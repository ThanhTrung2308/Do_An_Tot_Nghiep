# %%
import cloudscraper
from bs4 import BeautifulSoup
import re
import os
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import logging
from random_user_agent.user_agent import UserAgent
from random_user_agent.params import SoftwareName, OperatingSystem
import random
from aiohttp import ClientSession
import asyncio

# %%
async def handle_response_error(response):
    if response.status == 429:
        logging.error("Yêu cầu thất bại, mã lỗi 429 (Quá nhiều yêu cầu), đang thử lại sau 10 giây...")
        await asyncio.sleep(random.uniform(5, 7))
    elif response.status == 403:
        logging.error("Yêu cầu thất bại, mã lỗi 403 (Quá nhiều yêu cầu), đang thử lại sau 10 giây...")
        await asyncio.sleep(random.uniform(5, 7))
    else:
        print(f"Yêu cầu thất bại, mã lỗi: {response.status}")

async def fetch_all_players_data(session, player_links):
    semaphore = asyncio.Semaphore(6)  # Số lượng yêu cầu đồng thời
    tasks = []
    async def fetch_with_semaphore(url):
        async with semaphore:
            try:
                return await crawl_player_details(session, url)
            except ClientError as e:
                print(f"Error for URL {url}: {e}")
                return None
    
    for player_link in player_links:
        url = f"https://sofifa.com{player_link['href']}"
        if "/player/" in url and "/random" not in url:
            task = fetch_with_semaphore(url)
            tasks.append(task)
            
    return await asyncio.gather(*tasks)

async def crawl_all_players_data(year, file_path='D:/Jupyter/DATA/test4.csv'):
    base_url = f"https://sofifa.com/players?r={year}&set=true"
    #scraper = cloudscraper.create_scraper()
    data_frame = pd.DataFrame()
    page = 1
    has_players = True
    software_names = [SoftwareName.CHROME.value]
    operating_systems = [OperatingSystem.WINDOWS.value, OperatingSystem.LINUX.value]   
    user_agent_rotator = UserAgent(software_names=software_names, operating_systems=operating_systems, limit=1000)
    async with ClientSession() as session:
        #player_data_list = []
        while has_players:
            page_url = f"{base_url}&offset={((page - 1) * 61)}"
            headers = {'User-Agent': user_agent_rotator.get_random_user_agent()}
            response = await session.get(page_url, headers=headers)
            #time.sleep(3)
            if response.status == 200:
                soup = BeautifulSoup(await response.text(), 'html.parser')
                player_links = soup.find_all('a', href=lambda href: href and "/player/" in href)

                if not player_links:
                    has_players = False
                    break
                else:
                    data_frames = await fetch_all_players_data(session, player_links)
                    
                    for player_data in data_frames:
                        if player_data is not None:
                            df = pd.DataFrame([player_data])
                            file_exists = os.path.isfile(file_path)
                            df.to_csv(file_path, mode='a', header=not file_exists, index=False)
                    page += 1
                    #await asyncio.sleep(random.uniform(1, 3))  # Thêm thời gian chờ giữa các trang
            else:
                await handle_response_error(response)
    
    return data_frame

# %%
async def crawl_player_details(session, player_url):
    scraper = cloudscraper.create_scraper(
        browser={
        'browser': 'chrome',
        'platform': 'windows',
        'desktop': True,
        'mobile': False,
        'custom':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36 Edg/118.0.2088.46"
    }, delay = 5)
    response = await session.get(player_url)
    await asyncio.sleep(random.uniform(1, 3))
    if response.status == 200:
        soup = BeautifulSoup(await response.text(), 'html.parser')
        short_name = soup.find('h1', class_='ellipsis').text.strip()
        player_info = soup.find('div', class_='info')
        player_name = player_info.find('h1').text.strip()
        nationality = player_info.find('a', title=True)['title'] or "Không xác định"
        #Lấy thông tin chuỗi thông tin cơ bản
        meta_info = player_info.find('div', class_='meta ellipsis').text.strip()
        # Sử dụng biểu thức chính quy để trích xuất thông tin
        match = re.match(r'(.+?) (\d+)y\.o\. \((\w+ \d+, \d+)\) (\d+)cm / (\S+) (\d+)kg', meta_info)
        position = match.group(1)
        age = match.group(2)
        birthday = match.group(3)
        height = match.group(4)
        weight_unit = match.group(5)
        weight = match.group(6)
        player_info2 = soup.find('section', class_='card spacing')
        overall_rating = player_info2.find('div', string='Overall rating').find_previous('span').text.strip()
        potential = player_info2.find('div', string='Potential').find_previous('span').text.strip()
        value = player_info2.find('div', string='Value').previous_sibling.strip()
        wage = player_info2.find('div', string='Wage').previous_sibling.strip()
        #list chứa thông tin cầu thủ
        player_data = [
            ('Player URL', player_url),
            ('Short Name', short_name),
            ('Player Name', player_name),
            ('Nationality', nationality),
            ('Position', position),
            ('Age', age),
            ('Birthday', birthday),
            ('Height', height),
            ('Weight', weight),
            ('Overall Rating', overall_rating),
            ('Potential', potential),
            ('Value', value),
            ('Wage', wage),
            
        ]
        profile_divs = soup.find_all('div', class_='card')
        # Duyệt qua mỗi phần tử div 'card' và lấy dữ liệu
        for profile_div in profile_divs:
            
            ul_element_profile = profile_div.find('ul', class_='pl')
            
            # Kiểm tra xem thẻ <ul class="pl"> có tồn tại không
            if ul_element_profile:
                # Tìm tất cả các phần tử <li> trong thẻ <ul class="pl">
                li_elements_profile = ul_element_profile.find_all('li')
                
                for li in li_elements_profile:
                    # Lấy các thẻ con bên trong <li>
                    label_tag = li.find('label')
                    span_tag_profile = li.find('span')
                    has_svg = bool(li.find('svg'))
                    if label_tag:
                        attribute_name_profile = label_tag.text.strip()
                        
                        if span_tag_profile:
                            # Trường hợp có <span>, lấy giá trị từ <span>
                            attribute_value_profile = span_tag_profile.text.strip()
                        elif not has_svg:
                            # Trường hợp không có <span> và không có <svg>, lấy giá trị từ toàn bộ <li>
                            attribute_value_profile = li.text.strip().replace(attribute_name_profile, '')
                        else:
                            # Trường hợp có <svg>
                            attribute_value_profile = li.text.strip().replace(attribute_name_profile, '')
                            # Sử dụng biểu thức chính quy để lấy con số trước <svg>
                            match1 = re.search(r'\d+', attribute_value_profile)
                            attribute_value_profile = match1.group() if match1 else ""
                        
                        #print(f"{attribute_name_profile} {attribute_value_profile}")
                        player_data.append((attribute_name_profile, attribute_value_profile))
            h5_element = profile_div.find('h5')
            if h5_element:
                a_element = h5_element.find('a')
                if a_element:
                    club_link = a_element['href']
                    match = re.search(r'/team/\d+/(.*)/', club_link)
                    if match:
                        club_name = match.group(1)
                        #print(f"Club Name: {club_name}")
                        player_data.append(club_name)
            else:
                # Nếu không tìm thấy thẻ <ul class='pl'> trong thẻ div với class='card', bỏ qua và không in gì cả
                pass   
        
        card_divs = soup.find_all('div', class_='card') 
        for card_div in card_divs:
            # Tìm thẻ <ul class="pl">
            ul_element = card_div.find('ul', class_='pl')
            # Kiểm tra xem thẻ <ul class="pl"> có tồn tại không
            if ul_element:
                # Tìm tất cả các phần tử <li> trong thẻ <ul class="pl">
                li_elements = ul_element.find_all('li')
                
                # Trích xuất dữ liệu và in ra màn hình
                for li in li_elements:
                    span_tag = li.find('span', class_='bp3-tag')
                    attribute_name_span = li.find('span', role='tooltip')

                    # Kiểm tra xem cả hai thẻ có tồn tại không trước khi truy xuất text
                    if span_tag and attribute_name_span:
                        attribute_value = span_tag.text.strip()
                        attribute_name = attribute_name_span.text.strip() 
                        #print(f"{attribute_name} {attribute_value}")
                        player_data.append((attribute_name, attribute_value))
                    else:
                        # Nếu một số phần tử bị thiếu, bỏ qua và không in gì cả
                        pass      
            else:
                # Nếu không tìm thấy thẻ <ul class='pl'> trong thẻ div với class='card', bỏ qua và không in gì cả
                pass
        
        print(player_data)
        return player_data
    else:
        await handle_response_error(response)
        return None  # Trả về None nếu có lỗi

# %%
# final_df = pd.DataFrame()
# final_df = pd.concat([final_df, crawl_all_players_data(220069, num_threads=8)], ignore_index=True)
#print(data_frame)
await crawl_all_players_data(220069)
# Out:
# [('Player URL', 'https://sofifa.com/player/231747/kylian-mbappe/220069/'), ('Short Name', 'K. Mbappé'), ('Player Name', 'Kylian Mbappé Lottin'), ('Nationality', 'France'), ('Position', 'ST LW'), ('Age', '22'), ('Birthday', 'Dec 20, 1998'), ('Height', '182'), ('Weight', '73'), ('Overall Rating', '91'), ('Potential', '95'), ('Value', '€194M'), ('Wage', '€230K'), ('Preferred foot', 'Right'), ('Skill moves', '5'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'High/ Low'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€373.5M'), ('ID', '231747'), ('Position', 'ST'), ('Kit number', '7'), ('Joined', 'Jul 1, 2018'), ('Contract valid until', '2025'), 'paris-saint-germain', ('Position', 'LS'), ('Kit number', '10'), 'france', ('Crossing', '78'), ('Finishing', '93'), ('Heading accuracy', '72'), ('Short passing', '85'), ('Volleys', '83'), ('Dribbling', '93'), ('Curve', '80'), ('FK Accuracy', '69'), ('Long passing', '71'), ('Ball control', '91'), ('Acceleration', '97'), ('Sprint speed', '97'), ('Agility', '92'), ('Reactions', '93'), ('Balance', '83'), ('Shot power', '86'), ('Jumping', '78'), ('Stamina', '88'), ('Strength', '77'), ('Long shots', '82'), ('Aggression', '62'), ('Interceptions', '38'), ('Att. Position', '92'), ('Vision', '82'), ('Penalties', '79'), ('Composure', '88'), ('Defensive awareness', '26'), ('Standing tackle', '34'), ('Sliding tackle', '32'), ('GK Diving', '13'), ('GK Handling', '5'), ('GK Kicking', '7'), ('GK Positioning', '11'), ('GK Reflexes', '6')]
# [('Player URL', 'https://sofifa.com/player/192985/kevin-de-bruyne/220069/'), ('Short Name', 'K. De Bruyne'), ('Player Name', 'Kevin De Bruyne'), ('Nationality', 'Belgium'), ('Position', 'CM CAM'), ('Age', '30'), ('Birthday', 'Jun 28, 1991'), ('Height', '181'), ('Weight', '70'), ('Overall Rating', '91'), ('Potential', '91'), ('Value', '€125.5M'), ('Wage', '€350K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '5'), ('International reputation', '4'), ('Work rate', 'High/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€232.2M'), ('ID', '192985'), ('Position', 'RCM'), ('Kit number', '17'), ('Joined', 'Aug 30, 2015'), ('Contract valid until', '2025'), 'manchester-city', ('Position', 'RM'), ('Kit number', '7'), 'belgium', ('Crossing', '94'), ('Finishing', '83'), ('Heading accuracy', '55'), ('Short passing', '93'), ('Volleys', '83'), ('Dribbling', '88'), ('Curve', '85'), ('FK Accuracy', '83'), ('Long passing', '93'), ('Ball control', '90'), ('Acceleration', '76'), ('Sprint speed', '76'), ('Agility', '79'), ('Reactions', '91'), ('Balance', '78'), ('Shot power', '92'), ('Jumping', '63'), ('Stamina', '88'), ('Strength', '74'), ('Long shots', '91'), ('Aggression', '75'), ('Interceptions', '66'), ('Att. Position', '88'), ('Vision', '94'), ('Penalties', '83'), ('Composure', '89'), ('Defensive awareness', '68'), ('Standing tackle', '65'), ('Sliding tackle', '53'), ('GK Diving', '15'), ('GK Handling', '13'), ('GK Kicking', '5'), ('GK Positioning', '10'), ('GK Reflexes', '13')]
# [('Player URL', 'https://sofifa.com/player/209331/mohamed-salah/220069/'), ('Short Name', 'M. Salah'), ('Player Name', 'Mohamed Salah Ghaly'), ('Nationality', 'Egypt'), ('Position', 'RW'), ('Age', '29'), ('Birthday', 'Jun 15, 1992'), ('Height', '175'), ('Weight', '71'), ('Overall Rating', '91'), ('Potential', '91'), ('Value', '€129M'), ('Wage', '€350K'), ('Preferred foot', 'Left'), ('Skill moves', '4'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€238.7M'), ('ID', '209331'), ('Position', 'RW'), ('Kit number', '11'), ('Joined', 'Jul 1, 2017'), ('Contract valid until', '2023'), 'liverpool', ('Crossing', '81'), ('Finishing', '93'), ('Heading accuracy', '59'), ('Short passing', '85'), ('Volleys', '84'), ('Dribbling', '92'), ('Curve', '84'), ('FK Accuracy', '69'), ('Long passing', '77'), ('Ball control', '90'), ('Acceleration', '90'), ('Sprint speed', '91'), ('Agility', '91'), ('Reactions', '94'), ('Balance', '91'), ('Shot power', '83'), ('Jumping', '69'), ('Stamina', '87'), ('Strength', '75'), ('Long shots', '85'), ('Aggression', '63'), ('Interceptions', '55'), ('Att. Position', '92'), ('Vision', '86'), ('Penalties', '86'), ('Composure', '92'), ('Defensive awareness', '38'), ('Standing tackle', '43'), ('Sliding tackle', '41'), ('GK Diving', '14'), ('GK Handling', '14'), ('GK Kicking', '9'), ('GK Positioning', '11'), ('GK Reflexes', '14')]
# [('Player URL', 'https://sofifa.com/player/188545/robert-lewandowski/220069/'), ('Short Name', 'R. Lewandowski'), ('Player Name', 'Robert Lewandowski'), ('Nationality', 'Poland'), ('Position', 'ST'), ('Age', '32'), ('Birthday', 'Aug 21, 1988'), ('Height', '185'), ('Weight', '81'), ('Overall Rating', '92'), ('Potential', '92'), ('Value', '€119.5M'), ('Wage', '€270K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '5'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€197.2M'), ('ID', '188545'), ('Position', 'ST'), ('Kit number', '9'), ('Joined', 'Jul 1, 2014'), ('Contract valid until', '2023'), 'fc-bayern-munchen', ('Position', 'ST'), ('Kit number', '9'), 'poland', ('Crossing', '71'), ('Finishing', '95'), ('Heading accuracy', '90'), ('Short passing', '85'), ('Volleys', '89'), ('Dribbling', '85'), ('Curve', '79'), ('FK Accuracy', '85'), ('Long passing', '70'), ('Ball control', '88'), ('Acceleration', '77'), ('Sprint speed', '78'), ('Agility', '77'), ('Reactions', '93'), ('Balance', '82'), ('Shot power', '90'), ('Jumping', '85'), ('Stamina', '76'), ('Strength', '86'), ('Long shots', '87'), ('Aggression', '81'), ('Interceptions', '49'), ('Att. Position', '95'), ('Vision', '81'), ('Penalties', '90'), ('Composure', '88'), ('Defensive awareness', '35'), ('Standing tackle', '42'), ('Sliding tackle', '19'), ('GK Diving', '15'), ('GK Handling', '6'), ('GK Kicking', '12'), ('GK Positioning', '8'), ('GK Reflexes', '10')]
# [('Player URL', 'https://sofifa.com/player/165153/karim-benzema/220069/'), ('Short Name', 'K. Benzema'), ('Player Name', 'Karim Benzema'), ('Nationality', 'France'), ('Position', 'CF ST'), ('Age', '33'), ('Birthday', 'Dec 19, 1987'), ('Height', '185'), ('Weight', '81'), ('Overall Rating', '91'), ('Potential', '91'), ('Value', '€84M'), ('Wage', '€450K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Normal (170-185)'), ('Real face', 'Yes'), ('Release clause', '€172.2M'), ('ID', '165153'), ('Position', 'CF'), ('Kit number', '9'), ('Joined', 'Jul 9, 2009'), ('Contract valid until', '2023'), 'real-madrid', ('Crossing', '75'), ('Finishing', '92'), ('Heading accuracy', '90'), ('Short passing', '89'), ('Volleys', '88'), ('Dribbling', '87'), ('Curve', '82'), ('FK Accuracy', '73'), ('Long passing', '76'), ('Ball control', '91'), ('Acceleration', '79'), ('Sprint speed', '80'), ('Agility', '78'), ('Reactions', '92'), ('Balance', '72'), ('Shot power', '87'), ('Jumping', '79'), ('Stamina', '81'), ('Strength', '82'), ('Long shots', '80'), ('Aggression', '63'), ('Interceptions', '39'), ('Att. Position', '92'), ('Vision', '89'), ('Penalties', '84'), ('Composure', '90'), ('Defensive awareness', '43'), ('Standing tackle', '24'), ('Sliding tackle', '18'), ('GK Diving', '13'), ('GK Handling', '11'), ('GK Kicking', '5'), ('GK Positioning', '5'), ('GK Reflexes', '7')]
# [('Player URL', 'https://sofifa.com/player/158023/lionel-messi/220069/'), ('Short Name', 'L. Messi'), ('Player Name', 'Lionel Andrés Messi Cuccittini'), ('Nationality', 'Argentina'), ('Position', 'RW ST CF'), ('Age', '34'), ('Birthday', 'Jun 24, 1987'), ('Height', '169'), ('Weight', '67'), ('Overall Rating', '92'), ('Potential', '92'), ('Value', '€69.5M'), ('Wage', '€290K'), ('Preferred foot', 'Left'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '5'), ('Work rate', 'Low/ Low'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€128.6M'), ('ID', '158023'), ('Position', 'RW'), ('Kit number', '30'), ('Joined', 'Aug 10, 2021'), ('Contract valid until', '2023'), 'paris-saint-germain', ('Position', 'RW'), ('Kit number', '10'), 'argentina', ('Crossing', '85'), ('Finishing', '91'), ('Heading accuracy', '70'), ('Short passing', '91'), ('Volleys', '88'), ('Dribbling', '96'), ('Curve', '93'), ('FK Accuracy', '93'), ('Long passing', '91'), ('Ball control', '94'), ('Acceleration', '90'), ('Sprint speed', '78'), ('Agility', '91'), ('Reactions', '93'), ('Balance', '95'), ('Shot power', '86'), ('Jumping', '68'), ('Stamina', '71'), ('Strength', '69'), ('Long shots', '93'), ('Aggression', '44'), ('Interceptions', '40'), ('Att. Position', '93'), ('Vision', '95'), ('Penalties', '75'), ('Composure', '96'), ('Defensive awareness', '20'), ('Standing tackle', '35'), ('Sliding tackle', '24'), ('GK Diving', '6'), ('GK Handling', '11'), ('GK Kicking', '15'), ('GK Positioning', '14'), ('GK Reflexes', '8')]
# [('Player URL', 'https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/220069/'), ('Short Name', 'Cristiano Ronaldo'), ('Player Name', 'Cristiano Ronaldo dos Santos Aveiro'), ('Nationality', 'Portugal'), ('Position', 'ST'), ('Age', '36'), ('Birthday', 'Feb 5, 1985'), ('Height', '187'), ('Weight', '83'), ('Overall Rating', '91'), ('Potential', '91'), ('Value', '€45M'), ('Wage', '€270K'), ('Preferred foot', 'Right'), ('Skill moves', '5'), ('Weak foot', '4'), ('International reputation', '5'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€83.3M'), ('ID', '20801'), ('Position', 'ST'), ('Kit number', '7'), ('Joined', 'Aug 27, 2021'), ('Contract valid until', '2023'), 'manchester-united', ('Position', 'ST'), ('Kit number', '7'), 'portugal', ('Crossing', '84'), ('Finishing', '94'), ('Heading accuracy', '90'), ('Short passing', '80'), ('Volleys', '86'), ('Dribbling', '86'), ('Curve', '81'), ('FK Accuracy', '79'), ('Long passing', '77'), ('Ball control', '88'), ('Acceleration', '82'), ('Sprint speed', '87'), ('Agility', '82'), ('Reactions', '94'), ('Balance', '72'), ('Shot power', '94'), ('Jumping', '95'), ('Stamina', '77'), ('Strength', '77'), ('Long shots', '92'), ('Aggression', '63'), ('Interceptions', '29'), ('Att. Position', '95'), ('Vision', '76'), ('Penalties', '90'), ('Composure', '95'), ('Defensive awareness', '24'), ('Standing tackle', '32'), ('Sliding tackle', '24'), ('GK Diving', '7'), ('GK Handling', '11'), ('GK Kicking', '15'), ('GK Positioning', '14'), ('GK Reflexes', '11')]
# [('Player URL', 'https://sofifa.com/player/215914/ngolo-kante/220069/'), ('Short Name', 'N. Kanté'), ('Player Name', "N'Golo Kanté"), ('Nationality', 'France'), ('Position', 'CDM CM'), ('Age', '30'), ('Birthday', 'Mar 29, 1991'), ('Height', '168'), ('Weight', '70'), ('Overall Rating', '90'), ('Potential', '90'), ('Value', '€100M'), ('Wage', '€230K'), ('Preferred foot', 'Right'), ('Skill moves', '2'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'Medium/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€185M'), ('ID', '215914'), ('Position', 'RCM'), ('Kit number', '7'), ('Joined', 'Jul 16, 2016'), ('Contract valid until', '2023'), 'chelsea', ('Position', 'RDM'), ('Kit number', '13'), 'france', ('Crossing', '68'), ('Finishing', '65'), ('Heading accuracy', '54'), ('Short passing', '82'), ('Volleys', '56'), ('Dribbling', '79'), ('Curve', '49'), ('FK Accuracy', '49'), ('Long passing', '79'), ('Ball control', '81'), ('Acceleration', '82'), ('Sprint speed', '75'), ('Agility', '82'), ('Reactions', '93'), ('Balance', '92'), ('Shot power', '71'), ('Jumping', '77'), ('Stamina', '97'), ('Strength', '72'), ('Long shots', '65'), ('Aggression', '93'), ('Interceptions', '91'), ('Att. Position', '72'), ('Vision', '78'), ('Penalties', '54'), ('Composure', '84'), ('Defensive awareness', '90'), ('Standing tackle', '93'), ('Sliding tackle', '86'), ('GK Diving', '15'), ('GK Handling', '12'), ('GK Kicking', '10'), ('GK Positioning', '7'), ('GK Reflexes', '10')]
# [('Player URL', 'https://sofifa.com/player/203376/virgil-van-dijk/220069/'), ('Short Name', 'V. van Dijk'), ('Player Name', 'Virgil van Dijk'), ('Nationality', 'Netherlands'), ('Position', 'CB'), ('Age', '29'), ('Birthday', 'Jul 8, 1991'), ('Height', '193'), ('Weight', '92'), ('Overall Rating', '90'), ('Potential', '90'), ('Value', '€100M'), ('Wage', '€240K'), ('Preferred foot', 'Right'), ('Skill moves', '2'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€185M'), ('ID', '203376'), ('Position', 'LCB'), ('Kit number', '4'), ('Joined', 'Jan 1, 2018'), ('Contract valid until', '2025'), 'liverpool', ('Position', 'CB'), ('Kit number', '4'), 'netherlands', ('Crossing', '53'), ('Finishing', '52'), ('Heading accuracy', '87'), ('Short passing', '79'), ('Volleys', '45'), ('Dribbling', '70'), ('Curve', '60'), ('FK Accuracy', '70'), ('Long passing', '86'), ('Ball control', '76'), ('Acceleration', '70'), ('Sprint speed', '90'), ('Agility', '61'), ('Reactions', '89'), ('Balance', '53'), ('Shot power', '81'), ('Jumping', '88'), ('Stamina', '74'), ('Strength', '93'), ('Long shots', '64'), ('Aggression', '85'), ('Interceptions', '90'), ('Att. Position', '47'), ('Vision', '65'), ('Penalties', '62'), ('Composure', '90'), ('Defensive awareness', '92'), ('Standing tackle', '92'), ('Sliding tackle', '86'), ('GK Diving', '13'), ('GK Handling', '10'), ('GK Kicking', '13'), ('GK Positioning', '11'), ('GK Reflexes', '11')]
# [('Player URL', 'https://sofifa.com/player/167495/manuel-neuer/220069/'), ('Short Name', 'M. Neuer'), ('Player Name', 'Manuel Peter Neuer'), ('Nationality', 'Germany'), ('Position', 'GK'), ('Age', '35'), ('Birthday', 'Mar 27, 1986'), ('Height', '193'), ('Weight', '93'), ('Overall Rating', '90'), ('Potential', '90'), ('Value', '€13.5M'), ('Wage', '€86K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '4'), ('International reputation', '5'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€22.3M'), ('ID', '167495'), ('Position', 'GK'), ('Kit number', '1'), ('Joined', 'Jul 1, 2011'), ('Contract valid until', '2024'), 'fc-bayern-munchen', ('Position', 'GK'), ('Kit number', '1'), 'germany', ('Crossing', '15'), ('Finishing', '13'), ('Heading accuracy', '25'), ('Short passing', '60'), ('Volleys', '11'), ('Dribbling', '30'), ('Curve', '14'), ('FK Accuracy', '11'), ('Long passing', '68'), ('Ball control', '46'), ('Acceleration', '54'), ('Sprint speed', '60'), ('Agility', '51'), ('Reactions', '87'), ('Balance', '35'), ('Shot power', '68'), ('Jumping', '77'), ('Stamina', '43'), ('Strength', '80'), ('Long shots', '16'), ('Aggression', '29'), ('Interceptions', '30'), ('Att. Position', '12'), ('Vision', '70'), ('Penalties', '47'), ('Composure', '70'), ('Defensive awareness', '17'), ('Standing tackle', '10'), ('Sliding tackle', '11'), ('GK Diving', '88'), ('GK Handling', '88'), ('GK Kicking', '91'), ('GK Positioning', '89'), ('GK Reflexes', '88')]
# [('Player URL', 'https://sofifa.com/player/212831/alisson-ramses-becker/220069/'), ('Short Name', 'Alisson'), ('Player Name', 'Alisson Ramses Becker'), ('Nationality', 'Brazil'), ('Position', 'GK'), ('Age', '28'), ('Birthday', 'Oct 2, 1992'), ('Height', '191'), ('Weight', '91'), ('Overall Rating', '89'), ('Potential', '90'), ('Value', '€82M'), ('Wage', '€190K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€157.9M'), ('ID', '212831'), ('Position', 'GK'), ('Kit number', '1'), ('Joined', 'Jul 19, 2018'), ('Contract valid until', '2027'), 'liverpool', ('Crossing', '17'), ('Finishing', '13'), ('Heading accuracy', '29'), ('Short passing', '55'), ('Volleys', '20'), ('Dribbling', '27'), ('Curve', '19'), ('FK Accuracy', '18'), ('Long passing', '56'), ('Ball control', '40'), ('Acceleration', '56'), ('Sprint speed', '47'), ('Agility', '40'), ('Reactions', '87'), ('Balance', '37'), ('Shot power', '63'), ('Jumping', '52'), ('Stamina', '32'), ('Strength', '78'), ('Long shots', '14'), ('Aggression', '27'), ('Interceptions', '11'), ('Att. Position', '13'), ('Vision', '66'), ('Penalties', '23'), ('Composure', '68'), ('Defensive awareness', '15'), ('Standing tackle', '19'), ('Sliding tackle', '16'), ('GK Diving', '86'), ('GK Handling', '86'), ('GK Kicking', '84'), ('GK Positioning', '90'), ('GK Reflexes', '89')]
# [('Player URL', 'https://sofifa.com/player/190871/neymar-da-silva-santos-jr/220069/'), ('Short Name', 'Neymar Jr'), ('Player Name', 'Neymar da Silva Santos Júnior'), ('Nationality', 'Brazil'), ('Position', 'LW CAM'), ('Age', '29'), ('Birthday', 'Feb 5, 1992'), ('Height', '175'), ('Weight', '68'), ('Overall Rating', '90'), ('Potential', '90'), ('Value', '€117.5M'), ('Wage', '€220K'), ('Preferred foot', 'Right'), ('Skill moves', '5'), ('Weak foot', '5'), ('International reputation', '5'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€217.4M'), ('ID', '190871'), ('Position', 'LW'), ('Kit number', '10'), ('Joined', 'Aug 3, 2017'), ('Contract valid until', '2025'), 'paris-saint-germain', ('Crossing', '85'), ('Finishing', '83'), ('Heading accuracy', '63'), ('Short passing', '86'), ('Volleys', '86'), ('Dribbling', '95'), ('Curve', '88'), ('FK Accuracy', '87'), ('Long passing', '81'), ('Ball control', '95'), ('Acceleration', '91'), ('Sprint speed', '88'), ('Agility', '95'), ('Reactions', '89'), ('Balance', '84'), ('Shot power', '79'), ('Jumping', '64'), ('Stamina', '81'), ('Strength', '53'), ('Long shots', '81'), ('Aggression', '63'), ('Interceptions', '37'), ('Att. Position', '86'), ('Vision', '90'), ('Penalties', '91'), ('Composure', '93'), ('Defensive awareness', '35'), ('Standing tackle', '32'), ('Sliding tackle', '29'), ('GK Diving', '9'), ('GK Handling', '9'), ('GK Kicking', '15'), ('GK Positioning', '15'), ('GK Reflexes', '11')]
# [('Player URL', 'https://sofifa.com/player/212622/joshua-kimmich/220069/'), ('Short Name', 'J. Kimmich'), ('Player Name', 'Joshua Walter Kimmich'), ('Nationality', 'Germany'), ('Position', 'CDM RB'), ('Age', '26'), ('Birthday', 'Feb 8, 1995'), ('Height', '177'), ('Weight', '75'), ('Overall Rating', '89'), ('Potential', '90'), ('Value', '€108M'), ('Wage', '€160K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Normal (170-185)'), ('Real face', 'Yes'), ('Release clause', '€186.3M'), ('ID', '212622'), ('Position', 'RDM'), ('Kit number', '6'), ('Joined', 'Jul 1, 2015'), ('Contract valid until', '2025'), 'fc-bayern-munchen', ('Position', 'SUB'), ('Kit number', '6'), 'germany', ('Crossing', '91'), ('Finishing', '68'), ('Heading accuracy', '72'), ('Short passing', '87'), ('Volleys', '69'), ('Dribbling', '82'), ('Curve', '85'), ('FK Accuracy', '69'), ('Long passing', '90'), ('Ball control', '85'), ('Acceleration', '77'), ('Sprint speed', '65'), ('Agility', '84'), ('Reactions', '88'), ('Balance', '84'), ('Shot power', '78'), ('Jumping', '79'), ('Stamina', '94'), ('Strength', '68'), ('Long shots', '83'), ('Aggression', '89'), ('Interceptions', '84'), ('Att. Position', '80'), ('Vision', '85'), ('Penalties', '44'), ('Composure', '85'), ('Defensive awareness', '85'), ('Standing tackle', '85'), ('Sliding tackle', '78'), ('GK Diving', '8'), ('GK Handling', '15'), ('GK Kicking', '7'), ('GK Positioning', '15'), ('GK Reflexes', '15')]
# [('Player URL', 'https://sofifa.com/player/210257/ederson-santana-de-moraes/220069/'), ('Short Name', 'Ederson'), ('Player Name', 'Ederson Santana de Moraes'), ('Nationality', 'Brazil'), ('Position', 'GK'), ('Age', '27'), ('Birthday', 'Aug 17, 1993'), ('Height', '188'), ('Weight', '86'), ('Overall Rating', '89'), ('Potential', '91'), ('Value', '€94M'), ('Wage', '€200K'), ('Preferred foot', 'Left'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€181M'), ('ID', '210257'), ('Position', 'GK'), ('Kit number', '31'), ('Joined', 'Jul 1, 2017'), ('Contract valid until', '2026'), 'manchester-city', ('Crossing', '20'), ('Finishing', '14'), ('Heading accuracy', '14'), ('Short passing', '61'), ('Volleys', '18'), ('Dribbling', '23'), ('Curve', '15'), ('FK Accuracy', '20'), ('Long passing', '66'), ('Ball control', '40'), ('Acceleration', '64'), ('Sprint speed', '63'), ('Agility', '60'), ('Reactions', '88'), ('Balance', '48'), ('Shot power', '70'), ('Jumping', '66'), ('Stamina', '41'), ('Strength', '78'), ('Long shots', '18'), ('Aggression', '38'), ('Interceptions', '27'), ('Att. Position', '20'), ('Vision', '70'), ('Penalties', '51'), ('Composure', '70'), ('Defensive awareness', '29'), ('Standing tackle', '15'), ('Sliding tackle', '8'), ('GK Diving', '87'), ('GK Handling', '82'), ('GK Kicking', '93'), ('GK Positioning', '88'), ('GK Reflexes', '88')]
# [('Player URL', 'https://sofifa.com/player/208722/sadio-mane/220069/'), ('Short Name', 'S. Mané'), ('Player Name', 'Sadio Mané'), ('Nationality', 'Senegal'), ('Position', 'LW CF'), ('Age', '29'), ('Birthday', 'Apr 10, 1992'), ('Height', '175'), ('Weight', '69'), ('Overall Rating', '89'), ('Potential', '89'), ('Value', '€101M'), ('Wage', '€270K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€186.9M'), ('ID', '208722'), ('Position', 'LW'), ('Kit number', '10'), ('Joined', 'Jul 1, 2016'), ('Contract valid until', '2023'), 'liverpool', ('Crossing', '78'), ('Finishing', '86'), ('Heading accuracy', '84'), ('Short passing', '84'), ('Volleys', '75'), ('Dribbling', '88'), ('Curve', '77'), ('FK Accuracy', '64'), ('Long passing', '71'), ('Ball control', '86'), ('Acceleration', '92'), ('Sprint speed', '90'), ('Agility', '93'), ('Reactions', '91'), ('Balance', '88'), ('Shot power', '83'), ('Jumping', '87'), ('Stamina', '85'), ('Strength', '72'), ('Long shots', '78'), ('Aggression', '75'), ('Interceptions', '35'), ('Att. Position', '90'), ('Vision', '84'), ('Penalties', '75'), ('Composure', '84'), ('Defensive awareness', '42'), ('Standing tackle', '42'), ('Sliding tackle', '38'), ('GK Diving', '10'), ('GK Handling', '10'), ('GK Kicking', '15'), ('GK Positioning', '7'), ('GK Reflexes', '14')]
# [('Player URL', 'https://sofifa.com/player/202126/harry-kane/220069/'), ('Short Name', 'H. Kane'), ('Player Name', 'Harry Kane'), ('Nationality', 'England'), ('Position', 'ST'), ('Age', '27'), ('Birthday', 'Jul 28, 1993'), ('Height', '188'), ('Weight', '89'), ('Overall Rating', '89'), ('Potential', '89'), ('Value', '€112M'), ('Wage', '€230K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '5'), ('International reputation', '4'), ('Work rate', 'High/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€212.8M'), ('ID', '202126'), ('Position', 'ST'), ('Kit number', '10'), ('Joined', 'Jul 28, 2010'), ('Contract valid until', '2024'), 'tottenham-hotspur', ('Position', 'ST'), ('Kit number', '9'), 'england', ('Crossing', '80'), ('Finishing', '94'), ('Heading accuracy', '85'), ('Short passing', '84'), ('Volleys', '87'), ('Dribbling', '83'), ('Curve', '82'), ('FK Accuracy', '65'), ('Long passing', '85'), ('Ball control', '85'), ('Acceleration', '67'), ('Sprint speed', '69'), ('Agility', '68'), ('Reactions', '92'), ('Balance', '71'), ('Shot power', '92'), ('Jumping', '79'), ('Stamina', '83'), ('Strength', '84'), ('Long shots', '86'), ('Aggression', '80'), ('Interceptions', '44'), ('Att. Position', '94'), ('Vision', '87'), ('Penalties', '92'), ('Composure', '92'), ('Defensive awareness', '50'), ('Standing tackle', '36'), ('Sliding tackle', '38'), ('GK Diving', '8'), ('GK Handling', '10'), ('GK Kicking', '11'), ('GK Positioning', '14'), ('GK Reflexes', '11')]
# [('Player URL', 'https://sofifa.com/player/200389/jan-oblak/220069/'), ('Short Name', 'J. Oblak'), ('Player Name', 'Jan Oblak'), ('Nationality', 'Slovenia'), ('Position', 'GK'), ('Age', '28'), ('Birthday', 'Jan 7, 1993'), ('Height', '188'), ('Weight', '87'), ('Overall Rating', '89'), ('Potential', '91'), ('Value', '€88M'), ('Wage', '€100K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '5'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€187M'), ('ID', '200389'), ('Position', 'GK'), ('Kit number', '13'), ('Joined', 'Jul 16, 2014'), ('Contract valid until', '2023'), 'atletico-madrid', ('Crossing', '13'), ('Finishing', '11'), ('Heading accuracy', '15'), ('Short passing', '43'), ('Volleys', '13'), ('Dribbling', '12'), ('Curve', '13'), ('FK Accuracy', '14'), ('Long passing', '40'), ('Ball control', '30'), ('Acceleration', '43'), ('Sprint speed', '58'), ('Agility', '65'), ('Reactions', '87'), ('Balance', '49'), ('Shot power', '59'), ('Jumping', '77'), ('Stamina', '41'), ('Strength', '78'), ('Long shots', '12'), ('Aggression', '34'), ('Interceptions', '21'), ('Att. Position', '11'), ('Vision', '65'), ('Penalties', '11'), ('Composure', '68'), ('Defensive awareness', '27'), ('Standing tackle', '12'), ('Sliding tackle', '18'), ('GK Diving', '86'), ('GK Handling', '90'), ('GK Kicking', '78'), ('GK Positioning', '87'), ('GK Reflexes', '89')]
# [('Player URL', 'https://sofifa.com/player/200145/carlos-henrique-venancio-casimiro/220069/'), ('Short Name', 'Casemiro'), ('Player Name', 'Carlos Henrique Venancio Casimiro'), ('Nationality', 'Brazil'), ('Position', 'CDM'), ('Age', '29'), ('Birthday', 'Feb 23, 1992'), ('Height', '185'), ('Weight', '84'), ('Overall Rating', '89'), ('Potential', '89'), ('Value', '€88M'), ('Wage', '€310K'), ('Preferred foot', 'Right'), ('Skill moves', '2'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€180.4M'), ('ID', '200145'), ('Position', 'CDM'), ('Kit number', '14'), ('Joined', 'Jul 11, 2013'), ('Contract valid until', '2025'), 'real-madrid', ('Crossing', '58'), ('Finishing', '64'), ('Heading accuracy', '79'), ('Short passing', '84'), ('Volleys', '62'), ('Dribbling', '69'), ('Curve', '62'), ('FK Accuracy', '74'), ('Long passing', '84'), ('Ball control', '79'), ('Acceleration', '60'), ('Sprint speed', '69'), ('Agility', '61'), ('Reactions', '87'), ('Balance', '66'), ('Shot power', '88'), ('Jumping', '87'), ('Stamina', '89'), ('Strength', '90'), ('Long shots', '81'), ('Aggression', '91'), ('Interceptions', '87'), ('Att. Position', '75'), ('Vision', '80'), ('Penalties', '66'), ('Composure', '84'), ('Defensive awareness', '85'), ('Standing tackle', '88'), ('Sliding tackle', '87'), ('GK Diving', '13'), ('GK Handling', '14'), ('GK Kicking', '16'), ('GK Positioning', '12'), ('GK Reflexes', '12')]
# [('Player URL', 'https://sofifa.com/player/200104/heung-min-son/220069/'), ('Short Name', 'H. Son'), ('Player Name', '손흥민 孙兴慜'), ('Nationality', 'Korea Republic'), ('Position', 'LW LM ST'), ('Age', '28'), ('Birthday', 'Jul 8, 1992'), ('Height', '183'), ('Weight', '78'), ('Overall Rating', '89'), ('Potential', '89'), ('Value', '€104M'), ('Wage', '€240K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '5'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€197.6M'), ('ID', '200104'), ('Position', 'LW'), ('Kit number', '7'), ('Joined', 'Aug 28, 2015'), ('Contract valid until', '2025'), 'tottenham-hotspur', ('Crossing', '83'), ('Finishing', '89'), ('Heading accuracy', '68'), ('Short passing', '84'), ('Volleys', '79'), ('Dribbling', '87'), ('Curve', '85'), ('FK Accuracy', '74'), ('Long passing', '74'), ('Ball control', '84'), ('Acceleration', '85'), ('Sprint speed', '90'), ('Agility', '87'), ('Reactions', '91'), ('Balance', '79'), ('Shot power', '88'), ('Jumping', '60'), ('Stamina', '88'), ('Strength', '64'), ('Long shots', '89'), ('Aggression', '62'), ('Interceptions', '39'), ('Att. Position', '91'), ('Vision', '84'), ('Penalties', '73'), ('Composure', '89'), ('Defensive awareness', '47'), ('Standing tackle', '34'), ('Sliding tackle', '33'), ('GK Diving', '11'), ('GK Handling', '13'), ('GK Kicking', '13'), ('GK Positioning', '6'), ('GK Reflexes', '10')]
# [('Player URL', 'https://sofifa.com/player/239818/ruben-santos-gato-alves-dias/220069/'), ('Short Name', 'Rúben Dias'), ('Player Name', 'Rúben dos Santos Gato Alves Dias'), ('Nationality', 'Portugal'), ('Position', 'CB'), ('Age', '24'), ('Birthday', 'May 14, 1997'), ('Height', '187'), ('Weight', '82'), ('Overall Rating', '88'), ('Potential', '91'), ('Value', '€111.5M'), ('Wage', '€210K'), ('Preferred foot', 'Right'), ('Skill moves', '2'), ('Weak foot', '4'), ('International reputation', '3'), ('Work rate', 'Medium/ High'), ('Body type', 'Normal (185+)'), ('Real face', 'Yes'), ('Release clause', '€214.6M'), ('ID', '239818'), ('Position', 'RCB'), ('Kit number', '3'), ('Joined', 'Sep 29, 2020'), ('Contract valid until', '2027'), 'manchester-city', ('Position', 'LCB'), ('Kit number', '4'), 'portugal', ('Crossing', '54'), ('Finishing', '29'), ('Heading accuracy', '87'), ('Short passing', '82'), ('Volleys', '32'), ('Dribbling', '64'), ('Curve', '46'), ('FK Accuracy', '48'), ('Long passing', '76'), ('Ball control', '74'), ('Acceleration', '58'), ('Sprint speed', '69'), ('Agility', '61'), ('Reactions', '88'), ('Balance', '56'), ('Shot power', '74'), ('Jumping', '78'), ('Stamina', '87'), ('Strength', '89'), ('Long shots', '22'), ('Aggression', '92'), ('Interceptions', '85'), ('Att. Position', '39'), ('Vision', '51'), ('Penalties', '45'), ('Composure', '81'), ('Defensive awareness', '90'), ('Standing tackle', '89'), ('Sliding tackle', '85'), ('GK Diving', '7'), ('GK Handling', '8'), ('GK Kicking', '13'), ('GK Positioning', '7'), ('GK Reflexes', '12')]
# [('Player URL', 'https://sofifa.com/player/210514/joao-pedro-cavaco-cancelo/220069/'), ('Short Name', 'João Cancelo'), ('Player Name', 'João Pedro Cavaco Cancelo'), ('Nationality', 'Portugal'), ('Position', 'LB RB'), ('Age', '27'), ('Birthday', 'May 27, 1994'), ('Height', '182'), ('Weight', '74'), ('Overall Rating', '88'), ('Potential', '89'), ('Value', '€96M'), ('Wage', '€240K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '3'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€184.8M'), ('ID', '210514'), ('Position', 'LB'), ('Kit number', '27'), ('Joined', 'Aug 7, 2019'), ('Contract valid until', '2027'), 'manchester-city', ('Position', 'RB'), ('Kit number', '20'), 'portugal', ('Crossing', '88'), ('Finishing', '69'), ('Heading accuracy', '72'), ('Short passing', '88'), ('Volleys', '62'), ('Dribbling', '85'), ('Curve', '87'), ('FK Accuracy', '69'), ('Long passing', '79'), ('Ball control', '87'), ('Acceleration', '86'), ('Sprint speed', '84'), ('Agility', '80'), ('Reactions', '85'), ('Balance', '78'), ('Shot power', '80'), ('Jumping', '72'), ('Stamina', '90'), ('Strength', '62'), ('Long shots', '79'), ('Aggression', '73'), ('Interceptions', '82'), ('Att. Position', '81'), ('Vision', '84'), ('Penalties', '52'), ('Composure', '86'), ('Defensive awareness', '81'), ('Standing tackle', '84'), ('Sliding tackle', '80'), ('GK Diving', '6'), ('GK Handling', '9'), ('GK Kicking', '15'), ('GK Positioning', '14'), ('GK Reflexes', '14')]
# [('Player URL', 'https://sofifa.com/player/239085/erling-haaland/220069/'), ('Short Name', 'E. Haaland'), ('Player Name', 'Erling Braut Haaland'), ('Nationality', 'Norway'), ('Position', 'ST'), ('Age', '20'), ('Birthday', 'Jul 21, 2000'), ('Height', '194'), ('Weight', '94'), ('Overall Rating', '88'), ('Potential', '94'), ('Value', '€143.5M'), ('Wage', '€110K'), ('Preferred foot', 'Left'), ('Skill moves', '3'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€272.7M'), ('ID', '239085'), ('Position', 'ST'), ('Kit number', '9'), ('Joined', 'Jan 1, 2020'), ('Contract valid until', '2024'), 'borussia-dortmund', ('Position', 'ST'), ('Kit number', '9'), 'norway', ('Crossing', '47'), ('Finishing', '94'), ('Heading accuracy', '78'), ('Short passing', '74'), ('Volleys', '88'), ('Dribbling', '78'), ('Curve', '77'), ('FK Accuracy', '62'), ('Long passing', '51'), ('Ball control', '85'), ('Acceleration', '82'), ('Sprint speed', '93'), ('Agility', '77'), ('Reactions', '88'), ('Balance', '72'), ('Shot power', '94'), ('Jumping', '74'), ('Stamina', '82'), ('Strength', '93'), ('Long shots', '87'), ('Aggression', '85'), ('Interceptions', '43'), ('Att. Position', '89'), ('Vision', '73'), ('Penalties', '76'), ('Composure', '85'), ('Defensive awareness', '44'), ('Standing tackle', '53'), ('Sliding tackle', '29'), ('GK Diving', '7'), ('GK Handling', '14'), ('GK Kicking', '13'), ('GK Positioning', '11'), ('GK Reflexes', '7')]
# [('Player URL', 'https://sofifa.com/player/192119/thibaut-courtois/220069/'), ('Short Name', 'T. Courtois'), ('Player Name', 'Thibaut Nicolas Marc Courtois'), ('Nationality', 'Belgium'), ('Position', 'GK'), ('Age', '29'), ('Birthday', 'May 11, 1992'), ('Height', '199'), ('Weight', '96'), ('Overall Rating', '89'), ('Potential', '90'), ('Value', '€79M'), ('Wage', '€250K'), ('Preferred foot', 'Left'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€167.9M'), ('ID', '192119'), ('Position', 'GK'), ('Kit number', '1'), ('Joined', 'Aug 9, 2018'), ('Contract valid until', '2026'), 'real-madrid', ('Position', 'GK'), ('Kit number', '1'), 'belgium', ('Crossing', '14'), ('Finishing', '14'), ('Heading accuracy', '13'), ('Short passing', '33'), ('Volleys', '12'), ('Dribbling', '13'), ('Curve', '19'), ('FK Accuracy', '20'), ('Long passing', '35'), ('Ball control', '23'), ('Acceleration', '42'), ('Sprint speed', '52'), ('Agility', '62'), ('Reactions', '84'), ('Balance', '45'), ('Shot power', '56'), ('Jumping', '68'), ('Stamina', '38'), ('Strength', '70'), ('Long shots', '17'), ('Aggression', '23'), ('Interceptions', '15'), ('Att. Position', '13'), ('Vision', '44'), ('Penalties', '27'), ('Composure', '66'), ('Defensive awareness', '20'), ('Standing tackle', '18'), ('Sliding tackle', '16'), ('GK Diving', '84'), ('GK Handling', '89'), ('GK Kicking', '74'), ('GK Positioning', '86'), ('GK Reflexes', '88')]
# [('Player URL', 'https://sofifa.com/player/230621/gianluigi-donnarumma/220069/'), ('Short Name', 'G. Donnarumma'), ('Player Name', 'Gianluigi Donnarumma'), ('Nationality', 'Italy'), ('Position', 'GK'), ('Age', '22'), ('Birthday', 'Feb 25, 1999'), ('Height', '196'), ('Weight', '90'), ('Overall Rating', '88'), ('Potential', '92'), ('Value', '€106M'), ('Wage', '€110K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€204.1M'), ('ID', '230621'), ('Position', 'GK'), ('Kit number', '50'), ('Joined', 'Jul 15, 2021'), ('Contract valid until', '2026'), 'paris-saint-germain', ('Position', 'GK'), ('Kit number', '21'), 'italy', ('Crossing', '12'), ('Finishing', '12'), ('Heading accuracy', '12'), ('Short passing', '36'), ('Volleys', '8'), ('Dribbling', '28'), ('Curve', '12'), ('FK Accuracy', '14'), ('Long passing', '34'), ('Ball control', '30'), ('Acceleration', '50'), ('Sprint speed', '55'), ('Agility', '64'), ('Reactions', '85'), ('Balance', '38'), ('Shot power', '59'), ('Jumping', '72'), ('Stamina', '34'), ('Strength', '72'), ('Long shots', '18'), ('Aggression', '30'), ('Interceptions', '26'), ('Att. Position', '14'), ('Vision', '60'), ('Penalties', '24'), ('Composure', '65'), ('Defensive awareness', '20'), ('Standing tackle', '14'), ('Sliding tackle', '16'), ('GK Diving', '90'), ('GK Handling', '83'), ('GK Kicking', '79'), ('GK Positioning', '85'), ('GK Reflexes', '89')]
# [('Player URL', 'https://sofifa.com/player/209658/leon-goretzka/220069/'), ('Short Name', 'L. Goretzka'), ('Player Name', 'Leon Christoph Goretzka'), ('Nationality', 'Germany'), ('Position', 'CM CDM'), ('Age', '26'), ('Birthday', 'Feb 6, 1995'), ('Height', '189'), ('Weight', '82'), ('Overall Rating', '88'), ('Potential', '89'), ('Value', '€107M'), ('Wage', '€165K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€184.6M'), ('ID', '209658'), ('Position', 'LDM'), ('Kit number', '8'), ('Joined', 'Jul 1, 2018'), ('Contract valid until', '2026'), 'fc-bayern-munchen', ('Position', 'SUB'), ('Kit number', '8'), 'germany', ('Crossing', '75'), ('Finishing', '82'), ('Heading accuracy', '86'), ('Short passing', '86'), ('Volleys', '71'), ('Dribbling', '84'), ('Curve', '76'), ('FK Accuracy', '75'), ('Long passing', '85'), ('Ball control', '87'), ('Acceleration', '78'), ('Sprint speed', '82'), ('Agility', '76'), ('Reactions', '88'), ('Balance', '73'), ('Shot power', '85'), ('Jumping', '79'), ('Stamina', '86'), ('Strength', '88'), ('Long shots', '86'), ('Aggression', '82'), ('Interceptions', '86'), ('Att. Position', '85'), ('Vision', '84'), ('Penalties', '60'), ('Composure', '82'), ('Defensive awareness', '74'), ('Standing tackle', '85'), ('Sliding tackle', '78'), ('GK Diving', '13'), ('GK Handling', '8'), ('GK Kicking', '15'), ('GK Positioning', '11'), ('GK Reflexes', '9')]
# [('Player URL', 'https://sofifa.com/player/192448/marc-andre-ter-stegen/220069/'), ('Short Name', 'M. ter Stegen'), ('Player Name', 'Marc-André ter Stegen'), ('Nationality', 'Germany'), ('Position', 'GK'), ('Age', '29'), ('Birthday', 'Apr 30, 1992'), ('Height', '187'), ('Weight', '85'), ('Overall Rating', '88'), ('Potential', '89'), ('Value', '€70M'), ('Wage', '€230K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€148.8M'), ('ID', '192448'), ('Position', 'GK'), ('Kit number', '1'), ('Joined', 'Jul 1, 2014'), ('Contract valid until', '2025'), 'fc-barcelona', ('Position', 'SUB'), ('Kit number', '22'), 'germany', ('Crossing', '18'), ('Finishing', '14'), ('Heading accuracy', '11'), ('Short passing', '61'), ('Volleys', '14'), ('Dribbling', '21'), ('Curve', '18'), ('FK Accuracy', '12'), ('Long passing', '63'), ('Ball control', '30'), ('Acceleration', '45'), ('Sprint speed', '50'), ('Agility', '39'), ('Reactions', '85'), ('Balance', '43'), ('Shot power', '65'), ('Jumping', '79'), ('Stamina', '35'), ('Strength', '78'), ('Long shots', '10'), ('Aggression', '43'), ('Interceptions', '22'), ('Att. Position', '11'), ('Vision', '70'), ('Penalties', '25'), ('Composure', '70'), ('Defensive awareness', '25'), ('Standing tackle', '13'), ('Sliding tackle', '10'), ('GK Diving', '86'), ('GK Handling', '85'), ('GK Kicking', '87'), ('GK Positioning', '85'), ('GK Reflexes', '90')]
# [('Player URL', 'https://sofifa.com/player/177003/luka-modric/220069/'), ('Short Name', 'L. Modrić'), ('Player Name', 'Luka Modrić'), ('Nationality', 'Croatia'), ('Position', 'CM'), ('Age', '35'), ('Birthday', 'Sep 9, 1985'), ('Height', '172'), ('Weight', '66'), ('Overall Rating', '88'), ('Potential', '88'), ('Value', '€36.5M'), ('Wage', '€230K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Lean (170-185)'), ('Real face', 'Yes'), ('Release clause', '€74.8M'), ('ID', '177003'), ('Position', 'RCM'), ('Kit number', '10'), ('Joined', 'Aug 1, 2012'), ('Contract valid until', '2023'), 'real-madrid', ('Crossing', '86'), ('Finishing', '72'), ('Heading accuracy', '55'), ('Short passing', '91'), ('Volleys', '76'), ('Dribbling', '85'), ('Curve', '85'), ('FK Accuracy', '78'), ('Long passing', '90'), ('Ball control', '90'), ('Acceleration', '76'), ('Sprint speed', '70'), ('Agility', '91'), ('Reactions', '88'), ('Balance', '92'), ('Shot power', '79'), ('Jumping', '67'), ('Stamina', '83'), ('Strength', '58'), ('Long shots', '82'), ('Aggression', '62'), ('Interceptions', '80'), ('Att. Position', '78'), ('Vision', '90'), ('Penalties', '82'), ('Composure', '92'), ('Defensive awareness', '70'), ('Standing tackle', '75'), ('Sliding tackle', '72'), ('GK Diving', '13'), ('GK Handling', '9'), ('GK Kicking', '7'), ('GK Positioning', '14'), ('GK Reflexes', '9')]
# [('Player URL', 'https://sofifa.com/player/207865/marcos-aoas-correa/220069/'), ('Short Name', 'Marquinhos'), ('Player Name', 'Marcos Aoás Corrêa'), ('Nationality', 'Brazil'), ('Position', 'CB'), ('Age', '27'), ('Birthday', 'May 14, 1994'), ('Height', '183'), ('Weight', '75'), ('Overall Rating', '88'), ('Potential', '90'), ('Value', '€97.5M'), ('Wage', '€160K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ High'), ('Body type', 'Normal (170-185)'), ('Real face', 'Yes'), ('Release clause', '€187.7M'), ('ID', '207865'), ('Position', 'RCB'), ('Kit number', '5'), ('Joined', 'Jul 19, 2013'), ('Contract valid until', '2024'), 'paris-saint-germain', ('Crossing', '68'), ('Finishing', '59'), ('Heading accuracy', '88'), ('Short passing', '84'), ('Volleys', '35'), ('Dribbling', '69'), ('Curve', '58'), ('FK Accuracy', '32'), ('Long passing', '85'), ('Ball control', '79'), ('Acceleration', '79'), ('Sprint speed', '83'), ('Agility', '69'), ('Reactions', '88'), ('Balance', '67'), ('Shot power', '65'), ('Jumping', '92'), ('Stamina', '83'), ('Strength', '78'), ('Long shots', '45'), ('Aggression', '81'), ('Interceptions', '89'), ('Att. Position', '70'), ('Vision', '76'), ('Penalties', '52'), ('Composure', '86'), ('Defensive awareness', '90'), ('Standing tackle', '89'), ('Sliding tackle', '89'), ('GK Diving', '6'), ('GK Handling', '6'), ('GK Kicking', '12'), ('GK Positioning', '10'), ('GK Reflexes', '13')]
# [('Player URL', 'https://sofifa.com/player/193041/keylor-navas/220069/'), ('Short Name', 'K. Navas'), ('Player Name', 'Keylor Navas Gamboa'), ('Nationality', 'Costa Rica'), ('Position', 'GK'), ('Age', '34'), ('Birthday', 'Dec 15, 1986'), ('Height', '185'), ('Weight', '80'), ('Overall Rating', '88'), ('Potential', '88'), ('Value', '€15.5M'), ('Wage', '€130K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Normal (185+)'), ('Real face', 'Yes'), ('Release clause', '€28.7M'), ('ID', '193041'), ('Position', 'SUB'), ('Kit number', '1'), ('Joined', 'Sep 2, 2019'), ('Contract valid until', '2024'), 'paris-saint-germain', ('Crossing', '11'), ('Finishing', '15'), ('Heading accuracy', '11'), ('Short passing', '40'), ('Volleys', '11'), ('Dribbling', '24'), ('Curve', '21'), ('FK Accuracy', '15'), ('Long passing', '37'), ('Ball control', '30'), ('Acceleration', '54'), ('Sprint speed', '53'), ('Agility', '60'), ('Reactions', '85'), ('Balance', '61'), ('Shot power', '56'), ('Jumping', '74'), ('Stamina', '39'), ('Strength', '75'), ('Long shots', '13'), ('Aggression', '32'), ('Interceptions', '22'), ('Att. Position', '16'), ('Vision', '68'), ('Penalties', '25'), ('Composure', '67'), ('Defensive awareness', '28'), ('Standing tackle', '14'), ('Sliding tackle', '14'), ('GK Diving', '89'), ('GK Handling', '84'), ('GK Kicking', '75'), ('GK Positioning', '87'), ('GK Reflexes', '89')]
# [('Player URL', 'https://sofifa.com/player/182521/toni-kroos/220069/'), ('Short Name', 'T. Kroos'), ('Player Name', 'Toni Kroos'), ('Nationality', 'Germany'), ('Position', 'CM'), ('Age', '31'), ('Birthday', 'Jan 4, 1990'), ('Height', '183'), ('Weight', '76'), ('Overall Rating', '88'), ('Potential', '88'), ('Value', '€75M'), ('Wage', '€310K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '5'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Normal (170-185)'), ('Real face', 'Yes'), ('Release clause', '€153.8M'), ('ID', '182521'), ('Position', 'LCM'), ('Kit number', '8'), ('Joined', 'Jul 17, 2014'), ('Contract valid until', '2023'), 'real-madrid', ('Crossing', '88'), ('Finishing', '77'), ('Heading accuracy', '58'), ('Short passing', '93'), ('Volleys', '82'), ('Dribbling', '80'), ('Curve', '86'), ('FK Accuracy', '84'), ('Long passing', '93'), ('Ball control', '88'), ('Acceleration', '55'), ('Sprint speed', '52'), ('Agility', '63'), ('Reactions', '90'), ('Balance', '71'), ('Shot power', '89'), ('Jumping', '32'), ('Stamina', '75'), ('Strength', '72'), ('Long shots', '86'), ('Aggression', '60'), ('Interceptions', '80'), ('Att. Position', '76'), ('Vision', '90'), ('Penalties', '73'), ('Composure', '88'), ('Defensive awareness', '71'), ('Standing tackle', '73'), ('Sliding tackle', '60'), ('GK Diving', '10'), ('GK Handling', '11'), ('GK Kicking', '13'), ('GK Positioning', '7'), ('GK Reflexes', '10')]
# [('Player URL', 'https://sofifa.com/player/231281/trent-alexander-arnold/220069/'), ('Short Name', 'T. Alexander-Arnold'), ('Player Name', 'Trent Alexander-Arnold'), ('Nationality', 'England'), ('Position', 'RB'), ('Age', '22'), ('Birthday', 'Oct 7, 1998'), ('Height', '180'), ('Weight', '69'), ('Overall Rating', '87'), ('Potential', '90'), ('Value', '€102.5M'), ('Wage', '€150K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '4'), ('International reputation', '3'), ('Work rate', 'High/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€197.3M'), ('ID', '231281'), ('Position', 'RB'), ('Kit number', '66'), ('Joined', 'Oct 7, 2015'), ('Contract valid until', '2025'), 'liverpool', ('Crossing', '92'), ('Finishing', '62'), ('Heading accuracy', '69'), ('Short passing', '87'), ('Volleys', '63'), ('Dribbling', '78'), ('Curve', '87'), ('FK Accuracy', '85'), ('Long passing', '91'), ('Ball control', '86'), ('Acceleration', '78'), ('Sprint speed', '82'), ('Agility', '73'), ('Reactions', '83'), ('Balance', '73'), ('Shot power', '82'), ('Jumping', '66'), ('Stamina', '89'), ('Strength', '66'), ('Long shots', '75'), ('Aggression', '74'), ('Interceptions', '83'), ('Att. Position', '78'), ('Vision', '90'), ('Penalties', '55'), ('Composure', '82'), ('Defensive awareness', '79'), ('Standing tackle', '83'), ('Sliding tackle', '80'), ('GK Diving', '14'), ('GK Handling', '15'), ('GK Kicking', '14'), ('GK Positioning', '6'), ('GK Reflexes', '7')]
# ...
# [('Player URL', 'https://sofifa.com/player/211110/paulo-dybala/220069/'), ('Short Name', 'P. Dybala'), ('Player Name', 'Paulo Bruno Exequiel Dybala'), ('Nationality', 'Argentina'), ('Position', 'CF RW'), ('Age', '27'), ('Birthday', 'Nov 15, 1993'), ('Height', '177'), ('Weight', '75'), ('Overall Rating', '87'), ('Potential', '87'), ('Value', '€86.5M'), ('Wage', '€160K'), ('Preferred foot', 'Left'), ('Skill moves', '4'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'High/ Low'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€147.1M'), ('ID', '211110'), ('Position', 'CAM'), ('Kit number', '10'), ('Joined', 'Jul 1, 2015'), ('Contract valid until', '2022'), 'juventus', ('Position', 'SUB'), ('Kit number', '21'), 'argentina', ('Crossing', '82'), ('Finishing', '84'), ('Heading accuracy', '59'), ('Short passing', '87'), ('Volleys', '88'), ('Dribbling', '90'), ('Curve', '89'), ('FK Accuracy', '88'), ('Long passing', '79'), ('Ball control', '93'), ('Acceleration', '84'), ('Sprint speed', '76'), ('Agility', '88'), ('Reactions', '80'), ('Balance', '93'), ('Shot power', '84'), ('Jumping', '74'), ('Stamina', '69'), ('Strength', '60'), ('Long shots', '89'), ('Aggression', '43'), ('Interceptions', '42'), ('Att. Position', '82'), ('Vision', '91'), ('Penalties', '84'), ('Composure', '79'), ('Defensive awareness', '32'), ('Standing tackle', '41'), ('Sliding tackle', '39'), ('GK Diving', '5'), ('GK Handling', '4'), ('GK Kicking', '4'), ('GK Positioning', '5'), ('GK Reflexes', '8')]
# [('Player URL', 'https://sofifa.com/player/209499/fabio-henrique-tavares/220069/'), ('Short Name', 'Fabinho'), ('Player Name', 'Fábio Henrique Tavares'), ('Nationality', 'Brazil'), ('Position', 'CDM CB'), ('Age', '27'), ('Birthday', 'Oct 23, 1993'), ('Height', '188'), ('Weight', '78'), ('Overall Rating', '87'), ('Potential', '88'), ('Value', '€81.5M'), ('Wage', '€175K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '2'), ('International reputation', '3'), ('Work rate', 'Medium/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€156.9M'), ('ID', '209499'), ('Position', 'CDM'), ('Kit number', '3'), ('Joined', 'Jul 1, 2018'), ('Contract valid until', '2026'), 'liverpool', ('Crossing', '75'), ('Finishing', '63'), ('Heading accuracy', '75'), ('Short passing', '84'), ('Volleys', '47'), ('Dribbling', '78'), ('Curve', '71'), ('FK Accuracy', '53'), ('Long passing', '82'), ('Ball control', '81'), ('Acceleration', '65'), ('Sprint speed', '68'), ('Agility', '64'), ('Reactions', '86'), ('Balance', '64'), ('Shot power', '81'), ('Jumping', '75'), ('Stamina', '88'), ('Strength', '81'), ('Long shots', '70'), ('Aggression', '85'), ('Interceptions', '88'), ('Att. Position', '70'), ('Vision', '76'), ('Penalties', '90'), ('Composure', '85'), ('Defensive awareness', '86'), ('Standing tackle', '88'), ('Sliding tackle', '86'), ('GK Diving', '13'), ('GK Handling', '12'), ('GK Kicking', '6'), ('GK Positioning', '8'), ('GK Reflexes', '8')]
# [('Player URL', 'https://sofifa.com/player/199556/marco-verratti/220069/'), ('Short Name', 'M. Verratti'), ('Player Name', 'Marco Verratti'), ('Nationality', 'Italy'), ('Position', 'CM CAM'), ('Age', '28'), ('Birthday', 'Nov 5, 1992'), ('Height', '165'), ('Weight', '60'), ('Overall Rating', '87'), ('Potential', '87'), ('Value', '€79.5M'), ('Wage', '€155K'), ('Preferred foot', 'Right'), ('Skill moves', '4'), ('Weak foot', '4'), ('International reputation', '3'), ('Work rate', 'Medium/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€147.1M'), ('ID', '199556'), ('Position', 'CM'), ('Kit number', '6'), ('Joined', 'Jul 18, 2012'), ('Contract valid until', '2024'), 'paris-saint-germain', ('Position', 'LCM'), ('Kit number', '6'), 'italy', ('Crossing', '82'), ('Finishing', '60'), ('Heading accuracy', '57'), ('Short passing', '90'), ('Volleys', '64'), ('Dribbling', '91'), ('Curve', '85'), ('FK Accuracy', '64'), ('Long passing', '89'), ('Ball control', '92'), ('Acceleration', '68'), ('Sprint speed', '60'), ('Agility', '91'), ('Reactions', '87'), ('Balance', '94'), ('Shot power', '60'), ('Jumping', '67'), ('Stamina', '76'), ('Strength', '54'), ('Long shots', '58'), ('Aggression', '89'), ('Interceptions', '85'), ('Att. Position', '78'), ('Vision', '89'), ('Penalties', '64'), ('Composure', '94'), ('Defensive awareness', '78'), ('Standing tackle', '82'), ('Sliding tackle', '84'), ('GK Diving', '12'), ('GK Handling', '12'), ('GK Kicking', '15'), ('GK Positioning', '15'), ('GK Reflexes', '10')]
# [('Player URL', 'https://sofifa.com/player/193080/david-de-gea-quintana/220069/'), ('Short Name', 'De Gea'), ('Player Name', 'David De Gea Quintana'), ('Nationality', 'Spain'), ('Position', 'GK'), ('Age', '30'), ('Birthday', 'Nov 7, 1990'), ('Height', '192'), ('Weight', '76'), ('Overall Rating', '87'), ('Potential', '87'), ('Value', '€53M'), ('Wage', '€150K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '3'), ('International reputation', '4'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€98.1M'), ('ID', '193080'), ('Position', 'GK'), ('Kit number', '1'), ('Joined', 'Jul 1, 2011'), ('Contract valid until', '2023'), 'manchester-united', ('Position', 'SUB'), ('Kit number', '1'), 'spain', ('Crossing', '17'), ('Finishing', '13'), ('Heading accuracy', '21'), ('Short passing', '48'), ('Volleys', '13'), ('Dribbling', '18'), ('Curve', '21'), ('FK Accuracy', '19'), ('Long passing', '43'), ('Ball control', '38'), ('Acceleration', '57'), ('Sprint speed', '58'), ('Agility', '63'), ('Reactions', '89'), ('Balance', '43'), ('Shot power', '57'), ('Jumping', '67'), ('Stamina', '43'), ('Strength', '55'), ('Long shots', '12'), ('Aggression', '38'), ('Interceptions', '30'), ('Att. Position', '12'), ('Vision', '58'), ('Penalties', '29'), ('Composure', '60'), ('Defensive awareness', '25'), ('Standing tackle', '21'), ('Sliding tackle', '13'), ('GK Diving', '88'), ('GK Handling', '80'), ('GK Kicking', '76'), ('GK Positioning', '84'), ('GK Reflexes', '89')]
# [('Player URL', 'https://sofifa.com/player/189596/thomas-muller/220069/'), ('Short Name', 'T. Müller'), ('Player Name', 'Thomas Müller'), ('Nationality', 'Germany'), ('Position', 'CAM RM CF'), ('Age', '31'), ('Birthday', 'Sep 13, 1989'), ('Height', '185'), ('Weight', '76'), ('Overall Rating', '87'), ('Potential', '87'), ('Value', '€66M'), ('Wage', '€140K'), ('Preferred foot', 'Right'), ('Skill moves', '3'), ('Weak foot', '4'), ('International reputation', '4'), ('Work rate', 'High/ High'), ('Body type', 'Lean (185+)'), ('Real face', 'Yes'), ('Release clause', '€108.9M'), ('ID', '189596'), ('Position', 'CAM'), ('Kit number', '25'), ('Joined', 'Aug 10, 2008'), ('Contract valid until', '2024'), 'fc-bayern-munchen', ('Position', 'CAM'), ('Kit number', '13'), 'germany', ('Crossing', '85'), ('Finishing', '88'), ('Heading accuracy', '81'), ('Short passing', '85'), ('Volleys', '84'), ('Dribbling', '77'), ('Curve', '81'), ('FK Accuracy', '59'), ('Long passing', '79'), ('Ball control', '84'), ('Acceleration', '66'), ('Sprint speed', '68'), ('Agility', '72'), ('Reactions', '94'), ('Balance', '71'), ('Shot power', '78'), ('Jumping', '77'), ('Stamina', '86'), ('Strength', '66'), ('Long shots', '82'), ('Aggression', '62'), ('Interceptions', '58'), ('Att. Position', '96'), ('Vision', '86'), ('Penalties', '70'), ('Composure', '84'), ('Defensive awareness', '47'), ('Standing tackle', '57'), ('Sliding tackle', '46'), ('GK Diving', '6'), ('GK Handling', '7'), ('GK Kicking', '11'), ('GK Positioning', '14'), ('GK Reflexes', '14')]
# [('Player URL', 'https://sofifa.com/player/234642/edouard-mendy/220069/'), ('Short Name', 'É. Mendy'), ('Player Name', 'Édouard Mendy'), ('Nationality', 'Senegal'), ('Position', 'GK'), ('Age', '29'), ('Birthday', 'Mar 1, 1992'), ('Height', '197'), ('Weight', '86'), ('Overall Rating', '86'), ('Potential', '87'), ('Value', '€52M'), ('Wage', '€140K'), ('Preferred foot', 'Right'), ('Skill moves', '1'), ('Weak foot', '2'), ('International reputation', '2'), ('Work rate', 'Medium/ Medium'), ('Body type', 'Lean (185+)'), ('Real face', 'Yes'), ('Release clause', '€100.1M'), ('ID', '234642'), ('Position', 'GK'), ('Kit number', '16'), ('Joined', 'Sep 24, 2020'), ('Contract valid until', '2025'), 'chelsea', ('Crossing', '10'), ('Finishing', '5'), ('Heading accuracy', '10'), ('Short passing', '44'), ('Volleys', '9'), ('Dribbling', '13'), ('Curve', '13'), ('FK Accuracy', '14'), ('Long passing', '46'), ('Ball control', '31'), ('Acceleration', '36'), ('Sprint speed', '33'), ('Agility', '50'), ('Reactions', '86'), ('Balance', '33'), ('Shot power', '61'), ('Jumping', '39'), ('Stamina', '37'), ('Strength', '72'), ('Long shots', '9'), ('Aggression', '22'), ('Interceptions', '13'), ('Att. Position', '6'), ('Vision', '50'), ('Penalties', '13'), ('Composure', '58'), ('Defensive awareness', '10'), ('Standing tackle', '11'), ('Sliding tackle', '13'), ('GK Diving', '85'), ('GK Handling', '83'), ('GK Kicking', '81'), ('GK Positioning', '85'), ('GK Reflexes', '88')]
# [('Player URL', 'https://sofifa.com/player/232363/milan-skriniar/220069/'), ('Short Name', 'M. Škriniar'), ('Player Name', 'Milan Škriniar'), ('Nationality', 'Slovakia'), ('Position', 'CB'), ('Age', '26'), ('Birthday', 'Feb 11, 1995'), ('Height', '188'), ('Weight', '80'), ('Overall Rating', '86'), ('Potential', '87'), ('Value', '€70M'), ('Wage', '€150K'), ('Preferred foot', 'Right'), ('Skill moves', '2'), ('Weak foot', '3'), ('International reputation', '3'), ('Work rate', 'Low/ High'), ('Body type', 'Unique'), ('Real face', 'Yes'), ('Release clause', '€124.3M'), ('ID', '232363'), ('Position', 'RCB'), ('Kit number', '37'), ('Joined', 'Jul 7, 2017'), ('Contract valid until', '2023'), 'inter', ('Crossing', '40'), ('Finishing', '42'), ('Heading accuracy', '81'), ('Short passing', '70'), ('Volleys', '40'), ('Dribbling', '67'), ('Curve', '34'), ('FK Accuracy', '30'), ('Long passing', '63'), ('Ball control', '72'), ('Acceleration', '76'), ('Sprint speed', '84'), ('Agility', '54'), ('Reactions', '88'), ('Balance', '56'), ('Shot power', '50'), ('Jumping', '84'), ('Stamina', '82'), ('Strength', '89'), ('Long shots', '30'), ('Aggression', '82'), ('Interceptions', '86'), ('Att. Position', '30'), ('Vision', '46'), ('Penalties', '56'), ('Composure', '87'), ('Defensive awareness', '91'), ('Standing tackle', '90'), ('Sliding tackle', '80'), ('GK Diving', '10'), ('GK Handling', '13'), ('GK Kicking', '12'), ('GK Positioning', '8'), ('GK Reflexes', '12')]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> try:
# ---> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a>     return await crawl_player_details(session, url)
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> except ClientError as e:
#
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> response = await session.get(player_url)
# ---> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> await asyncio.sleep(random.uniform(1, 3))
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> if response.status == 200:
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:639, in sleep(delay, result)
#     638 try:
# --> 639     return await future
#     640 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # final_df = pd.DataFrame()
#       <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> # final_df = pd.concat([final_df, crawl_all_players_data(220069, num_threads=8)], ignore_index=True)
#       <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> #print(data_frame)
# ----> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> await crawl_all_players_data(220069)
#
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 5
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=51'>52</a>     break
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a> else:
# ---> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a>     data_frames = await fetch_all_players_data(session, player_links)
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=55'>56</a>     for player_data in data_frames:
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=56'>57</a>         if player_data is not None:
#
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>         task = fetch_with_semaphore(url)
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a>         tasks.append(task)
# ---> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a> return await asyncio.gather(*tasks)
#
# d:\Jupyter\DO_AN\Crawl-data.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> try:
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a>     return await crawl_player_details(session, url)
# ---> <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> except ClientError as e:
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a>     print(f"Error for URL {url}: {e}")
#      <a href='vscode-notebook-cell:/d%3A/Jupyter/DO_AN/Crawl-data.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a>     return None
#
# NameError: name 'ClientError' is not defined

# %%
import pandas as pd
data_frame = pd.read_csv('D:/Jupyter/DATA/Final_Crawl.csv',header=None)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18736\2492001212.py:2: DtypeWarning: Columns (28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv('D:/Jupyter/DATA/Final_Crawl.csv',header=None)

# %%
pd.set_option('display.max_columns', 100)
#pd.set_option('display.max_rows', 100)
data_frame.head(10)
# Out:
#                                                   0   \
# 0                                         PLAYER_URL
# 1  ('Player URL', 'https://sofifa.com/player/2326...
# 2  ('Player URL', 'https://sofifa.com/player/2382...
# 3  ('Player URL', 'https://sofifa.com/player/1865...
# 4  ('Player URL', 'https://sofifa.com/player/2365...
# 5  ('Player URL', 'https://sofifa.com/player/2330...
# 6  ('Player URL', 'https://sofifa.com/player/2026...
# 7  ('Player URL', 'https://sofifa.com/player/2530...
# 8  ('Player URL', 'https://sofifa.com/player/2002...
# 9  ('Player URL', 'https://sofifa.com/player/1895...
#
#                                1                                         2   \
# 0                      Short Name                               Player Name
# 1      ('Short Name', 'S. Singh')         ('Player Name', 'Sarpreet Singh')
# 2     ('Short Name', 'D. Gazdag')          ('Player Name', 'Dániel Gazdag')
# 3     ('Short Name', 'A. Ramsey')     ('Player Name', 'Aaron James Ramsey')
# 4     ('Short Name', 'J. Sýkora')             ('Player Name', 'Jan Sýkora')
# 5      ('Short Name', 'M. Mount')            ('Player Name', 'Mason Mount')
# 6     ('Short Name', 'D. Horgan')  ('Player Name', 'Daryl Jeremiah Horgan')
# 7  ('Short Name', 'G. Raspadori')      ('Player Name', 'Giacomo Raspadori')
# 8   ('Short Name', 'S. Berghuis')        ('Player Name', 'Steven Berghuis')
# 9     ('Short Name', 'T. Müller')          ('Player Name', 'Thomas Müller')
#
#                                        3                          4   \
# 0                             Nationality            Player_Position
# 1          ('Nationality', 'New Zealand')     ('Position', 'CAM RM')
# 2              ('Nationality', 'Hungary')     ('Position', 'CAM CM')
# 3                ('Nationality', 'Wales')  ('Position', 'CM CAM LM')
# 4       ('Nationality', 'Czech Republic')  ('Position', 'LM LB CAM')
# 5              ('Nationality', 'England')     ('Position', 'CAM RW')
# 6  ('Nationality', 'Republic of Ireland')        ('Position', 'CAM')
# 7                ('Nationality', 'Italy')      ('Position', 'ST LW')
# 8          ('Nationality', 'Netherlands')     ('Position', 'CAM RW')
# 9              ('Nationality', 'Germany')  ('Position', 'CAM RM CF')
#
#               5                             6                  7   \
# 0            Age                      Birthday         Height(cm)
# 1  ('Age', '22')  ('Birthday', 'Feb 20, 1999')  ('Height', '177')
# 2  ('Age', '25')   ('Birthday', 'Mar 2, 1996')  ('Height', '178')
# 3  ('Age', '30')  ('Birthday', 'Dec 26, 1990')  ('Height', '183')
# 4  ('Age', '27')  ('Birthday', 'Dec 29, 1993')  ('Height', '171')
# 5  ('Age', '22')  ('Birthday', 'Jan 10, 1999')  ('Height', '180')
# 6  ('Age', '28')  ('Birthday', 'Aug 10, 1992')  ('Height', '170')
# 7  ('Age', '21')  ('Birthday', 'Feb 18, 2000')  ('Height', '172')
# 8  ('Age', '29')  ('Birthday', 'Dec 19, 1991')  ('Height', '182')
# 9  ('Age', '31')  ('Birthday', 'Sep 13, 1989')  ('Height', '185')
#
#                  8                         9                    10  \
# 0        Weight(kg)            Overall Rating            Potential
# 1  ('Weight', '70')  ('Overall Rating', '69')  ('Potential', '78')
# 2  ('Weight', '76')  ('Overall Rating', '69')  ('Potential', '72')
# 3  ('Weight', '76')  ('Overall Rating', '77')  ('Potential', '77')
# 4  ('Weight', '64')  ('Overall Rating', '73')  ('Potential', '73')
# 5  ('Weight', '74')  ('Overall Rating', '83')  ('Potential', '89')
# 6  ('Weight', '70')  ('Overall Rating', '66')  ('Potential', '66')
# 7  ('Weight', '69')  ('Overall Rating', '76')  ('Potential', '85')
# 8  ('Weight', '75')  ('Overall Rating', '82')  ('Potential', '82')
# 9  ('Weight', '76')  ('Overall Rating', '87')  ('Potential', '87')
#
#                     11                 12                           13  \
# 0                Value               Wage               Preferred foot
# 1   ('Value', '€3.1M')    ('Wage', '€5K')   ('Preferred foot', 'Left')
# 2   ('Value', '€1.8M')    ('Wage', '€4K')  ('Preferred foot', 'Right')
# 3    ('Value', '€10M')   ('Wage', '€65K')  ('Preferred foot', 'Right')
# 4   ('Value', '€3.2M')   ('Wage', '€950')   ('Preferred foot', 'Left')
# 5  ('Value', '€58.5M')  ('Wage', '€120K')  ('Preferred foot', 'Right')
# 6   ('Value', '€850K')    ('Wage', '€3K')  ('Preferred foot', 'Right')
# 7    ('Value', '€17M')   ('Wage', '€25K')  ('Preferred foot', 'Right')
# 8    ('Value', '€30M')   ('Wage', '€26K')   ('Preferred foot', 'Left')
# 9    ('Value', '€66M')  ('Wage', '€140K')  ('Preferred foot', 'Right')
#
#                      14                  15  \
# 0           Skill moves           Weak foot
# 1  ('Skill moves', '3')  ('Weak foot', '3')
# 2  ('Skill moves', '3')  ('Weak foot', '3')
# 3  ('Skill moves', '3')  ('Weak foot', '3')
# 4  ('Skill moves', '3')  ('Weak foot', '3')
# 5  ('Skill moves', '3')  ('Weak foot', '4')
# 6  ('Skill moves', '4')  ('Weak foot', '4')
# 7  ('Skill moves', '4')  ('Weak foot', '5')
# 8  ('Skill moves', '4')  ('Weak foot', '3')
# 9  ('Skill moves', '3')  ('Weak foot', '4')
#
#                                   16                               17  \
# 0           International reputation                        Work rate
# 1  ('International reputation', '1')    ('Work rate', 'High/ Medium')
# 2  ('International reputation', '1')    ('Work rate', 'High/ Medium')
# 3  ('International reputation', '3')  ('Work rate', 'Medium/ Medium')
# 4  ('International reputation', '1')      ('Work rate', 'High/ High')
# 5  ('International reputation', '3')      ('Work rate', 'High/ High')
# 6  ('International reputation', '1')  ('Work rate', 'Medium/ Medium')
# 7  ('International reputation', '2')       ('Work rate', 'High/ Low')
# 8  ('International reputation', '2')    ('Work rate', 'High/ Medium')
# 9  ('International reputation', '4')      ('Work rate', 'High/ High')
#
#                                   18                    19  \
# 0                          Body type             Real face
# 1    ('Body type', 'Lean (170-185)')   ('Real face', 'No')
# 2  ('Body type', 'Normal (170-185)')   ('Real face', 'No')
# 3    ('Body type', 'Lean (170-185)')  ('Real face', 'Yes')
# 4    ('Body type', 'Lean (170-185)')   ('Real face', 'No')
# 5    ('Body type', 'Lean (170-185)')  ('Real face', 'Yes')
# 6     ('Body type', 'Normal (170-)')   ('Real face', 'No')
# 7  ('Body type', 'Normal (170-185)')   ('Real face', 'No')
# 8    ('Body type', 'Lean (170-185)')  ('Real face', 'Yes')
# 9       ('Body type', 'Lean (185+)')  ('Real face', 'Yes')
#
#                               20                21                   22  \
# 0                 Release clause                ID        Club_Position
# 1    ('Release clause', '€5.4M')  ('ID', '232669')  ('Position', 'LAM')
# 2    ('Release clause', '€2.8M')  ('ID', '238277')  ('Position', 'SUB')
# 3                            NaN  ('ID', '186561')  ('Position', 'SUB')
# 4      ('Release clause', '€7M')  ('ID', '236547')  ('Position', 'SUB')
# 5  ('Release clause', '€119.9M')  ('ID', '233064')  ('Position', 'CAM')
# 6    ('Release clause', '€1.5M')  ('ID', '202663')  ('Position', 'SUB')
# 7   ('Release clause', '€32.3M')  ('ID', '253002')  ('Position', 'SUB')
# 8     ('Release clause', '€42M')  ('ID', '200260')  ('Position', 'RCM')
# 9  ('Release clause', '€108.9M')  ('ID', '189596')  ('Position', 'CAM')
#
#                      23                          24  \
# 0       Club_Kit number                      Joined
# 1  ('Kit number', '15')   ('Joined', 'Jul 1, 2019')
# 2  ('Kit number', '15')  ('Joined', 'May 11, 2021')
# 3  ('Kit number', '16')                         NaN
# 4  ('Kit number', '18')  ('Joined', 'Aug 24, 2020')
# 5  ('Kit number', '19')  ('Joined', 'Jan 10, 2016')
# 6  ('Kit number', '19')   ('Joined', 'Sep 2, 2020')
# 7  ('Kit number', '22')  ('Joined', 'May 26, 2019')
# 8  ('Kit number', '23')  ('Joined', 'Jul 19, 2021')
# 9  ('Kit number', '25')  ('Joined', 'Aug 10, 2008')
#
#                             25                                        26  \
# 0                      Loaned                       Contract valid until
# 1                          NaN          ('Contract valid until', '2024')
# 2                          NaN          ('Contract valid until', '2022')
# 3  ('Loaned from', 'Juventus')  ('Contract valid until', 'May 31, 2022')
# 4                          NaN          ('Contract valid until', '2024')
# 5                          NaN          ('Contract valid until', '2024')
# 6                          NaN          ('Contract valid until', '2023')
# 7                          NaN          ('Contract valid until', '2024')
# 8                          NaN          ('Contract valid until', '2025')
# 9                          NaN          ('Contract valid until', '2024')
#
#                    27                   28                    29  \
# 0           Club_name    National_Position   National_Kit number
# 1     jahn-regensburg  ('Position', 'CAM')  ('Kit number', '10')
# 2  philadelphia-union  ('Position', 'CAM')   ('Kit number', '6')
# 3             rangers  ('Position', 'CAM')  ('Kit number', '20')
# 4      viktoria-plzen  ('Position', 'CAM')   ('Kit number', '7')
# 5             chelsea  ('Position', 'CAM')  ('Kit number', '19')
# 6   wycombe-wanderers  ('Position', 'CAM')  ('Kit number', '17')
# 7            sassuolo  ('Position', 'CAM')  ('Kit number', '18')
# 8                ajax  ('Position', 'CAM')  ('Kit number', '11')
# 9   fc-bayern-munchen  ('Position', 'CAM')  ('Kit number', '13')
#
#                     30                  31                   32  \
# 0        National_name  attacking_crossing  attacking_finishing
# 1          new-zealand  ('Crossing', '67')  ('Finishing', '64')
# 2              hungary  ('Crossing', '51')  ('Finishing', '66')
# 3                wales  ('Crossing', '70')  ('Finishing', '65')
# 4       czech-republic  ('Crossing', '74')  ('Finishing', '63')
# 5              england  ('Crossing', '83')  ('Finishing', '80')
# 6  republic-of-ireland  ('Crossing', '65')  ('Finishing', '60')
# 7                italy  ('Crossing', '43')  ('Finishing', '79')
# 8          netherlands  ('Crossing', '84')  ('Finishing', '81')
# 9              germany  ('Crossing', '85')  ('Finishing', '88')
#
#                            33                       34                 35  \
# 0  attacking_heading_accuracy  attacking_short_passing  attacking_volleys
# 1  ('Heading accuracy', '44')  ('Short passing', '70')  ('Volleys', '60')
# 2  ('Heading accuracy', '47')  ('Short passing', '70')  ('Volleys', '59')
# 3  ('Heading accuracy', '55')  ('Short passing', '80')  ('Volleys', '75')
# 4  ('Heading accuracy', '52')  ('Short passing', '70')  ('Volleys', '64')
# 5  ('Heading accuracy', '59')  ('Short passing', '86')  ('Volleys', '75')
# 6  ('Heading accuracy', '51')  ('Short passing', '64')  ('Volleys', '54')
# 7  ('Heading accuracy', '69')  ('Short passing', '77')  ('Volleys', '68')
# 8  ('Heading accuracy', '48')  ('Short passing', '83')  ('Volleys', '76')
# 9  ('Heading accuracy', '81')  ('Short passing', '85')  ('Volleys', '84')
#
#                     36               37                     38  \
# 0      skill_dribbling      skill_curve      skill_fk_accuracy
# 1  ('Dribbling', '71')  ('Curve', '73')  ('FK Accuracy', '64')
# 2  ('Dribbling', '72')  ('Curve', '61')  ('FK Accuracy', '60')
# 3  ('Dribbling', '79')  ('Curve', '79')  ('FK Accuracy', '70')
# 4  ('Dribbling', '75')  ('Curve', '69')  ('FK Accuracy', '70')
# 5  ('Dribbling', '82')  ('Curve', '82')  ('FK Accuracy', '83')
# 6  ('Dribbling', '66')  ('Curve', '69')  ('FK Accuracy', '67')
# 7  ('Dribbling', '79')  ('Curve', '62')  ('FK Accuracy', '60')
# 8  ('Dribbling', '82')  ('Curve', '86')  ('FK Accuracy', '76')
# 9  ('Dribbling', '77')  ('Curve', '81')  ('FK Accuracy', '59')
#
#                        39                      40                      41  \
# 0      skill_long_passing      skill_ball_control   movement_acceleration
# 1  ('Long passing', '69')  ('Ball control', '70')  ('Acceleration', '80')
# 2  ('Long passing', '68')  ('Ball control', '71')  ('Acceleration', '73')
# 3  ('Long passing', '78')  ('Ball control', '82')  ('Acceleration', '55')
# 4  ('Long passing', '64')  ('Ball control', '72')  ('Acceleration', '81')
# 5  ('Long passing', '83')  ('Ball control', '85')  ('Acceleration', '77')
# 6  ('Long passing', '59')  ('Ball control', '66')  ('Acceleration', '83')
# 7  ('Long passing', '52')  ('Ball control', '81')  ('Acceleration', '85')
# 8  ('Long passing', '82')  ('Ball control', '84')  ('Acceleration', '83')
# 9  ('Long passing', '79')  ('Ball control', '84')  ('Acceleration', '66')
#
#                        42                 43                   44  \
# 0   movement_sprint_speed   movement_agility   movement_reactions
# 1  ('Sprint speed', '70')  ('Agility', '78')  ('Reactions', '66')
# 2  ('Sprint speed', '78')  ('Agility', '71')  ('Reactions', '68')
# 3  ('Sprint speed', '63')  ('Agility', '68')  ('Reactions', '73')
# 4  ('Sprint speed', '81')  ('Agility', '84')  ('Reactions', '67')
# 5  ('Sprint speed', '73')  ('Agility', '80')  ('Reactions', '84')
# 6  ('Sprint speed', '82')  ('Agility', '90')  ('Reactions', '59')
# 7  ('Sprint speed', '77')  ('Agility', '77')  ('Reactions', '77')
# 8  ('Sprint speed', '78')  ('Agility', '84')  ('Reactions', '79')
# 9  ('Sprint speed', '68')  ('Agility', '72')  ('Reactions', '94')
#
#                   45                    46                 47  \
# 0   movement_balance      power_shot_power      power_jumping
# 1  ('Balance', '81')  ('Shot power', '68')  ('Jumping', '53')
# 2  ('Balance', '67')  ('Shot power', '64')  ('Jumping', '59')
# 3  ('Balance', '78')  ('Shot power', '76')  ('Jumping', '63')
# 4  ('Balance', '83')  ('Shot power', '74')  ('Jumping', '73')
# 5  ('Balance', '76')  ('Shot power', '81')  ('Jumping', '54')
# 6  ('Balance', '90')  ('Shot power', '64')  ('Jumping', '81')
# 7  ('Balance', '85')  ('Shot power', '72')  ('Jumping', '60')
# 8  ('Balance', '75')  ('Shot power', '82')  ('Jumping', '56')
# 9  ('Balance', '71')  ('Shot power', '78')  ('Jumping', '77')
#
#                   48                  49                    50  \
# 0      power_stamina      power_strength      power_long_shots
# 1  ('Stamina', '66')  ('Strength', '51')  ('Long shots', '67')
# 2  ('Stamina', '65')  ('Strength', '59')  ('Long shots', '63')
# 3  ('Stamina', '54')  ('Strength', '65')  ('Long shots', '75')
# 4  ('Stamina', '76')  ('Strength', '57')  ('Long shots', '72')
# 5  ('Stamina', '86')  ('Strength', '58')  ('Long shots', '82')
# 6  ('Stamina', '75')  ('Strength', '55')  ('Long shots', '60')
# 7  ('Stamina', '67')  ('Strength', '55')  ('Long shots', '72')
# 8  ('Stamina', '79')  ('Strength', '61')  ('Long shots', '85')
# 9  ('Stamina', '86')  ('Strength', '66')  ('Long shots', '82')
#
#                      51                       52                     53  \
# 0  mentality_aggression  mentality_interceptions  mentality_positioning
# 1  ('Aggression', '63')  ('Interceptions', '51')  ('Positioning', '60')
# 2  ('Aggression', '65')  ('Interceptions', '60')  ('Positioning', '64')
# 3  ('Aggression', '65')  ('Interceptions', '65')  ('Positioning', '75')
# 4  ('Aggression', '84')  ('Interceptions', '63')  ('Positioning', '69')
# 5  ('Aggression', '68')  ('Interceptions', '59')  ('Positioning', '81')
# 6  ('Aggression', '40')  ('Interceptions', '16')  ('Positioning', '63')
# 7  ('Aggression', '45')  ('Interceptions', '18')  ('Positioning', '78')
# 8  ('Aggression', '70')  ('Interceptions', '37')  ('Positioning', '80')
# 9  ('Aggression', '62')  ('Interceptions', '58')  ('Positioning', '96')
#
#                  54                   55                   56  \
# 0  mentality_vision  mentality_penalties  mentality_composure
# 1  ('Vision', '72')  ('Penalties', '64')  ('Composure', '64')
# 2  ('Vision', '68')  ('Penalties', '48')  ('Composure', '60')
# 3  ('Vision', '79')  ('Penalties', '75')  ('Composure', '77')
# 4  ('Vision', '68')  ('Penalties', '65')  ('Composure', '70')
# 5  ('Vision', '83')  ('Penalties', '69')  ('Composure', '84')
# 6  ('Vision', '65')  ('Penalties', '59')  ('Composure', '62')
# 7  ('Vision', '67')  ('Penalties', '76')  ('Composure', '75')
# 8  ('Vision', '83')  ('Penalties', '84')  ('Composure', '80')
# 9  ('Vision', '86')  ('Penalties', '70')  ('Composure', '84')
#
#                               57                         58  \
# 0              defending_marking  defending_standing_tackle
# 1  ('Defensive awareness', '51')  ('Standing tackle', '47')
# 2  ('Defensive awareness', '44')  ('Standing tackle', '53')
# 3  ('Defensive awareness', '66')  ('Standing tackle', '67')
# 4  ('Defensive awareness', '59')  ('Standing tackle', '67')
# 5  ('Defensive awareness', '55')  ('Standing tackle', '57')
# 6  ('Defensive awareness', '48')  ('Standing tackle', '26')
# 7  ('Defensive awareness', '21')  ('Standing tackle', '23')
# 8  ('Defensive awareness', '41')  ('Standing tackle', '36')
# 9  ('Defensive awareness', '47')  ('Standing tackle', '57')
#
#                          59                   60                     61  \
# 0  defending_sliding_tackle   goalkeeping_diving   goalkeeping_handling
# 1  ('Sliding tackle', '41')  ('GK Diving', '14')   ('GK Handling', '6')
# 2  ('Sliding tackle', '49')  ('GK Diving', '11')   ('GK Handling', '7')
# 3  ('Sliding tackle', '67')   ('GK Diving', '6')  ('GK Handling', '11')
# 4  ('Sliding tackle', '66')   ('GK Diving', '6')   ('GK Handling', '7')
# 5  ('Sliding tackle', '41')  ('GK Diving', '11')  ('GK Handling', '12')
# 6  ('Sliding tackle', '20')   ('GK Diving', '7')  ('GK Handling', '13')
# 7  ('Sliding tackle', '21')  ('GK Diving', '13')  ('GK Handling', '14')
# 8  ('Sliding tackle', '30')   ('GK Diving', '9')  ('GK Handling', '11')
# 9  ('Sliding tackle', '46')   ('GK Diving', '6')   ('GK Handling', '7')
#
#                      62                        63                     64
# 0   goalkeeping_kicking   goalkeeping_positioning   goalkeeping_reflexes
# 1  ('GK Kicking', '12')   ('GK Positioning', '8')   ('GK Reflexes', '8')
# 2   ('GK Kicking', '5')  ('GK Positioning', '11')  ('GK Reflexes', '11')
# 3   ('GK Kicking', '5')      ('GK Reflexes', '8')                    NaN
# 4  ('GK Kicking', '10')   ('GK Positioning', '9')  ('GK Reflexes', '13')
# 5  ('GK Kicking', '13')   ('GK Positioning', '8')  ('GK Reflexes', '12')
# 6  ('GK Kicking', '15')  ('GK Positioning', '12')   ('GK Reflexes', '7')
# 7   ('GK Kicking', '7')   ('GK Positioning', '7')   ('GK Reflexes', '9')
# 8   ('GK Kicking', '7')   ('GK Positioning', '7')  ('GK Reflexes', '15')
# 9  ('GK Kicking', '11')  ('GK Positioning', '14')  ('GK Reflexes', '14')

# %%
import ast

# Đọc DataFrame từ file CSV

# Hàm xử lý để loại bỏ key và giữ lại giá trị
def process_data(x):
    try:
        return ast.literal_eval(x)[1]
    except:
        return x

# Áp dụng hàm xử lý cho toàn bộ DataFrame
df = data_frame.applymap(process_data)

# Xuất ra CSV hoặc hiển thị DataFrame
df.to_csv('output1.csv', index=False, encoding='utf-8-sig')  # Xuất DataFrame ra file CSV
print(df)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18736\853689266.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = data_frame.applymap(process_data)
#                                                       0               1   \
# 0                                             PLAYER_URL      Short Name
# 1      https://sofifa.com/player/232669/sarpreet-sing...        S. Singh
# 2      https://sofifa.com/player/238277/daniel-gazdag...       D. Gazdag
# 3      https://sofifa.com/player/186561/aaron-ramsey/...       A. Ramsey
# 4      https://sofifa.com/player/236547/jan-sykora/22...       J. Sýkora
# ...                                                  ...             ...
# 18838  https://sofifa.com/player/263248/ioannis-tsout...   I. Tsoutsouki
# 18839  https://sofifa.com/player/140814/stavros-georg...     S. Georgiou
# 18840  https://sofifa.com/player/263249/stylianos-vro...      S. Vrontis
# 18841  https://sofifa.com/player/262563/marios-kokkin...  M. Kokkinoftas
# 18842  https://sofifa.com/player/267767/stefanos-kitt...       S. Kittos
#
#                        2               3                4    5             6   \
# 0             Player Name     Nationality  Player_Position  Age      Birthday
# 1          Sarpreet Singh     New Zealand           CAM RM   22  Feb 20, 1999
# 2           Dániel Gazdag         Hungary           CAM CM   25   Mar 2, 1996
# 3      Aaron James Ramsey           Wales        CM CAM LM   30  Dec 26, 1990
# 4              Jan Sýkora  Czech Republic        LM LB CAM   27  Dec 29, 1993
# ...                   ...             ...              ...  ...           ...
# 18838  Ioannis Tsoutsouki          Cyprus        CDM CM CB   17  Apr 14, 2004
# 18839    Stavros Georgiou          Cyprus         CF RW LW   16  Oct 19, 2004
# 18840   Stylianos Vrontis          Cyprus        CM RM CAM   16   Nov 5, 2004
# 18841  Marios Kokκinoftas          Cyprus           CDM CB   18  Mar 15, 2003
# 18842    Stephanos Kittos          Cyprus               GK   19  Feb 23, 2002
#
#                7           8               9          10     11    12  \
# 0      Height(cm)  Weight(kg)  Overall Rating  Potential  Value  Wage
# 1             177          70              69         78  €3.1M   €5K
# 2             178          76              69         72  €1.8M   €4K
# 3             183          76              77         77   €10M  €65K
# 4             171          64              73         73  €3.2M  €950
# ...           ...         ...             ...        ...    ...   ...
# 18838         181          72              53         70     €0    €0
# 18839         183          77              53         68     €0    €0
# 18840         178          65              53         68     €0    €0
# 18841         185          73              57         70     €0    €0
# 18842         186          75              58         68     €0    €0
#
#                    13           14         15                        16  \
# 0      Preferred foot  Skill moves  Weak foot  International reputation
# 1                Left            3          3                         1
# 2               Right            3          3                         1
# 3               Right            3          3                         3
# 4                Left            3          3                         1
# ...               ...          ...        ...                       ...
# 18838           Right            3          3                         1
# 18839           Right            3          3                         1
# 18840           Right            3          3                         1
# 18841           Right            2          3                         1
# 18842           Right            1          2                         1
#
#                    17                18         19              20      21  \
# 0           Work rate         Body type  Real face  Release clause      ID
# 1        High/ Medium    Lean (170-185)         No           €5.4M  232669
# 2        High/ Medium  Normal (170-185)         No           €2.8M  238277
# 3      Medium/ Medium    Lean (170-185)        Yes             NaN  186561
# 4          High/ High    Lean (170-185)         No             €7M  236547
# ...               ...               ...        ...             ...     ...
# 18838    Medium/ High  Normal (170-185)         No             NaN  263248
# 18839    High/ Medium  Normal (170-185)         No             NaN  140814
# 18840    High/ Medium  Normal (170-185)         No             NaN  263249
# 18841  Medium/ Medium       Lean (185+)         No             NaN  262563
# 18842  Medium/ Medium       Lean (185+)         No             NaN  267767
#
#                   22               23            24        25  \
# 0      Club_Position  Club_Kit number        Joined   Loaned
# 1                LAM               15   Jul 1, 2019       NaN
# 2                SUB               15  May 11, 2021       NaN
# 3                SUB               16           NaN  Juventus
# 4                SUB               18  Aug 24, 2020       NaN
# ...              ...              ...           ...       ...
# 18838            NaN              NaN           NaN       NaN
# 18839            NaN              NaN           NaN       NaN
# 18840            NaN              NaN           NaN       NaN
# 18841            NaN              NaN           NaN       NaN
# 18842            NaN              NaN           NaN       NaN
#
#                          26                  27                 28  \
# 0      Contract valid until           Club_name  National_Position
# 1                      2024     jahn-regensburg                CAM
# 2                      2022  philadelphia-union                CAM
# 3              May 31, 2022             rangers                CAM
# 4                      2024      viktoria-plzen                CAM
# ...                     ...                 ...                ...
# 18838                   NaN                 NaN                NaN
# 18839                   NaN                 NaN                NaN
# 18840                   NaN                 NaN                NaN
# 18841                   NaN                 NaN                NaN
# 18842                   NaN                 NaN                NaN
#
#                         29              30                  31  \
# 0      National_Kit number   National_name  attacking_crossing
# 1                       10     new-zealand                  67
# 2                        6         hungary                  51
# 3                       20           wales                  70
# 4                        7  czech-republic                  74
# ...                    ...             ...                 ...
# 18838                  NaN             NaN                  38
# 18839                  NaN             NaN                  33
# 18840                  NaN             NaN                  30
# 18841                  NaN             NaN                  26
# 18842                  NaN             NaN                  12
#
#                         32                          33  \
# 0      attacking_finishing  attacking_heading_accuracy
# 1                       64                          44
# 2                       66                          47
# 3                       65                          55
# 4                       63                          52
# ...                    ...                         ...
# 18838                   33                          42
# 18839                   51                          55
# 18840                   42                          41
# 18841                   21                          44
# 18842                    9                          14
#
#                             34                 35               36  \
# 0      attacking_short_passing  attacking_volleys  skill_dribbling
# 1                           70                 60               71
# 2                           70                 59               72
# 3                           80                 75               79
# 4                           70                 64               75
# ...                        ...                ...              ...
# 18838                       57                 29               44
# 18839                       45                 49               57
# 18840                       56                 31               54
# 18841                       60                 26               22
# 18842                       23                  5               11
#
#                 37                 38                  39                  40  \
# 0      skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control
# 1               73                 64                  69                  70
# 2               61                 60                  68                  71
# 3               79                 70                  78                  82
# 4               69                 70                  64                  72
# ...            ...                ...                 ...                 ...
# 18838           32                 39                  57                  60
# 18839           49                 34                  31                  50
# 18840           36                 39                  51                  60
# 18841           31                 28                  30                  60
# 18842           18                 10                  19                  21
#
#                           41                     42                43  \
# 0      movement_acceleration  movement_sprint_speed  movement_agility
# 1                         80                     70                78
# 2                         73                     78                71
# 3                         55                     63                68
# 4                         81                     81                84
# ...                      ...                    ...               ...
# 18838                     55                     60                54
# 18839                     67                     64                60
# 18840                     60                     63                60
# 18841                     58                     63                46
# 18842                     22                     27                31
#
#                        44                45                46             47  \
# 0      movement_reactions  movement_balance  power_shot_power  power_jumping
# 1                      66                81                68             53
# 2                      68                67                64             59
# 3                      73                78                76             63
# 4                      67                83                74             73
# ...                   ...               ...               ...            ...
# 18838                  54                72                40             59
# 18839                  52                49                49             52
# 18840                  49                52                52             60
# 18841                  67                57                30             69
# 18842                  41                34                41             52
#
#                   48              49                50                    51  \
# 0      power_stamina  power_strength  power_long_shots  mentality_aggression
# 1                 66              51                67                    63
# 2                 65              59                63                    65
# 3                 54              65                75                    65
# 4                 76              57                72                    84
# ...              ...             ...               ...                   ...
# 18838             53              50                32                    53
# 18839             60              63                45                    61
# 18840             61              49                39                    52
# 18841             63              51                16                    55
# 18842             26              43                 9                    21
#
#                             52                     53                54  \
# 0      mentality_interceptions  mentality_positioning  mentality_vision
# 1                           51                     60                72
# 2                           60                     64                68
# 3                           65                     75                79
# 4                           63                     69                68
# ...                        ...                    ...               ...
# 18838                       47                     39                41
# 18839                       51                     52                60
# 18840                       39                     50                60
# 18841                       59                     36                35
# 18842                        9                      5                44
#
#                         55                   56                 57  \
# 0      mentality_penalties  mentality_composure  defending_marking
# 1                       64                   64                 51
# 2                       48                   60                 44
# 3                       75                   77                 66
# 4                       65                   70                 59
# ...                    ...                  ...                ...
# 18838                   42                   37                 54
# 18839                   29                   47                 36
# 18840                   43                   42                 32
# 18841                   35                   58                 64
# 18842                   16                   35                 11
#
#                               58                        59  \
# 0      defending_standing_tackle  defending_sliding_tackle
# 1                             47                        41
# 2                             53                        49
# 3                             67                        67
# 4                             67                        66
# ...                          ...                       ...
# 18838                         46                        49
# 18839                         36                        38
# 18840                         44                        41
# 18841                         62                        54
# 18842                         13                        14
#
#                        60                    61                   62  \
# 0      goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking
# 1                      14                     6                   12
# 2                      11                     7                    5
# 3                       6                    11                    5
# 4                       6                     7                   10
# ...                   ...                   ...                  ...
# 18838                  10                    10                   13
# 18839                  16                     8                   14
# 18840                   9                    12                    6
# 18841                   7                    15                   11
# 18842                  62                    59                   55
#
#                             63                    64
# 0      goalkeeping_positioning  goalkeeping_reflexes
# 1                            8                     8
# 2                           11                    11
# 3                            8                   NaN
# 4                            9                    13
# ...                        ...                   ...
# 18838                        6                    14
# 18839                        7                    13
# 18840                       12                    10
# 18841                       11                    15
# 18842                       54                    60
#
# [18843 rows x 65 columns]

# %%
df.to_csv('test.csv')
